# %% [markdown]
# # análise exploratória tabela de movimentações

# %% [markdown]
# ## Setups

# %% [markdown]
# ### Definição de constantes

# %%
GCP_PROJECT_ID = "pure-league-482018-a7"
DATASET_NAME = "basedosdados"
SCHEMA_NAME = "br_me_caged"
TABLE= "microdados_movimentacao_fora_prazo"

# %% [markdown]
# ### Configurações de ambiente

# %%
from google.cloud import bigquery
from pathlib import Path
import os
import warnings

actual_path = Path().absolute()
os.chdir(actual_path.parent.parent.parent)

warnings.filterwarnings("ignore", category=UserWarning, module="google.cloud.bigquery")
client = bigquery.Client(project=GCP_PROJECT_ID)

# %% [markdown]
# ## análise de metadados

# %%
query_metadata_t1 = f"""
    SELECT *
    FROM `{DATASET_NAME}.{SCHEMA_NAME}.INFORMATION_SCHEMA.COLUMNS`
    WHERE table_name = '{TABLE}';
"""

df_metadata_t1 = client.query(query_metadata_t1).to_dataframe()
df_metadata_t1
# Out:
#    table_catalog table_schema                          table_name  \
# 0   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 1   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 2   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 3   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 4   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 5   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 6   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 7   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 8   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 9   basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 10  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 11  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 12  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 13  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 14  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 15  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 16  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 17  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 18  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 19  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 20  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 21  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 22  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 23  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 24  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 25  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
# 26  basedosdados  br_me_caged  microdados_movimentacao_fora_prazo
#
#                         column_name  ordinal_position is_nullable data_type  \
# 0                               ano                 1         YES     INT64
# 1                               mes                 2         YES     INT64
# 2      ano_competencia_movimentacao                 3         YES     INT64
# 3      mes_competencia_movimentacao                 4         YES     INT64
# 4                          sigla_uf                 5         YES    STRING
# 5                      id_municipio                 6         YES    STRING
# 6                      cnae_2_secao                 7         YES    STRING
# 7                  cnae_2_subclasse                 8         YES    STRING
# 8                saldo_movimentacao                 9         YES     INT64
# 9                          cbo_2002                10         YES    STRING
# 10                        categoria                11         YES    STRING
# 11                   grau_instrucao                12         YES    STRING
# 12                            idade                13         YES     INT64
# 13                horas_contratuais                14         YES   FLOAT64
# 14                         raca_cor                15         YES    STRING
# 15                             sexo                16         YES    STRING
# 16                  tipo_empregador                17         YES    STRING
# 17             tipo_estabelecimento                18         YES    STRING
# 18                tipo_movimentacao                19         YES    STRING
# 19                 tipo_deficiencia                20         YES    STRING
# 20  indicador_trabalho_intermitente                21         YES    STRING
# 21       indicador_trabalho_parcial                22         YES    STRING
# 22                   salario_mensal                23         YES   FLOAT64
# 23  tamanho_estabelecimento_janeiro                24         YES    STRING
# 24               indicador_aprendiz                25         YES    STRING
# 25                origem_informacao                26         YES    STRING
# 26             indicador_fora_prazo                27         YES     INT64
#
#    is_generated generation_expression is_stored  ... is_system_defined  \
# 0         NEVER                   NaN       NaN  ...                NO
# 1         NEVER                   NaN       NaN  ...                NO
# 2         NEVER                   NaN       NaN  ...                NO
# 3         NEVER                   NaN       NaN  ...                NO
# 4         NEVER                   NaN       NaN  ...                NO
# 5         NEVER                   NaN       NaN  ...                NO
# 6         NEVER                   NaN       NaN  ...                NO
# 7         NEVER                   NaN       NaN  ...                NO
# 8         NEVER                   NaN       NaN  ...                NO
# 9         NEVER                   NaN       NaN  ...                NO
# 10        NEVER                   NaN       NaN  ...                NO
# 11        NEVER                   NaN       NaN  ...                NO
# 12        NEVER                   NaN       NaN  ...                NO
# 13        NEVER                   NaN       NaN  ...                NO
# 14        NEVER                   NaN       NaN  ...                NO
# 15        NEVER                   NaN       NaN  ...                NO
# 16        NEVER                   NaN       NaN  ...                NO
# 17        NEVER                   NaN       NaN  ...                NO
# 18        NEVER                   NaN       NaN  ...                NO
# 19        NEVER                   NaN       NaN  ...                NO
# 20        NEVER                   NaN       NaN  ...                NO
# 21        NEVER                   NaN       NaN  ...                NO
# 22        NEVER                   NaN       NaN  ...                NO
# 23        NEVER                   NaN       NaN  ...                NO
# 24        NEVER                   NaN       NaN  ...                NO
# 25        NEVER                   NaN       NaN  ...                NO
# 26        NEVER                   NaN       NaN  ...                NO
#
#    is_partitioning_column clustering_ordinal_position collation_name  \
# 0                     YES                        <NA>           NULL
# 1                      NO                        <NA>           NULL
# 2                      NO                        <NA>           NULL
# 3                      NO                        <NA>           NULL
# 4                      NO                        <NA>           NULL
# 5                      NO                        <NA>           NULL
# 6                      NO                        <NA>           NULL
# 7                      NO                        <NA>           NULL
# 8                      NO                        <NA>           NULL
# 9                      NO                        <NA>           NULL
# 10                     NO                        <NA>           NULL
# 11                     NO                        <NA>           NULL
# 12                     NO                        <NA>           NULL
# 13                     NO                        <NA>           NULL
# 14                     NO                        <NA>           NULL
# 15                     NO                        <NA>           NULL
# 16                     NO                        <NA>           NULL
# 17                     NO                        <NA>           NULL
# 18                     NO                        <NA>           NULL
# 19                     NO                        <NA>           NULL
# 20                     NO                        <NA>           NULL
# 21                     NO                        <NA>           NULL
# 22                     NO                        <NA>           NULL
# 23                     NO                        <NA>           NULL
# 24                     NO                        <NA>           NULL
# 25                     NO                        <NA>           NULL
# 26                     NO                        <NA>           NULL
#
#     column_default rounding_mode data_policies data_governance_tags  \
# 0             NULL           NaN            []                   []
# 1             NULL           NaN            []                   []
# 2             NULL           NaN            []                   []
# 3             NULL           NaN            []                   []
# 4             NULL           NaN            []                   []
# 5             NULL           NaN            []                   []
# 6             NULL           NaN            []                   []
# 7             NULL           NaN            []                   []
# 8             NULL           NaN            []                   []
# 9             NULL           NaN            []                   []
# 10            NULL           NaN            []                   []
# 11            NULL           NaN            []                   []
# 12            NULL           NaN            []                   []
# 13            NULL           NaN            []                   []
# 14            NULL           NaN            []                   []
# 15            NULL           NaN            []                   []
# 16            NULL           NaN            []                   []
# 17            NULL           NaN            []                   []
# 18            NULL           NaN            []                   []
# 19            NULL           NaN            []                   []
# 20            NULL           NaN            []                   []
# 21            NULL           NaN            []                   []
# 22            NULL           NaN            []                   []
# 23            NULL           NaN            []                   []
# 24            NULL           NaN            []                   []
# 25            NULL           NaN            []                   []
# 26            NULL           NaN            []                   []
#
#    policy_tags async_generation_status
# 0           []                    None
# 1           []                    None
# 2           []                    None
# 3           []                    None
# 4           []                    None
# 5           []                    None
# 6           []                    None
# 7           []                    None
# 8           []                    None
# 9           []                    None
# 10          []                    None
# 11          []                    None
# 12          []                    None
# 13          []                    None
# 14          []                    None
# 15          []                    None
# 16          []                    None
# 17          []                    None
# 18          []                    None
# 19          []                    None
# 20          []                    None
# 21          []                    None
# 22          []                    None
# 23          []                    None
# 24          []                    None
# 25          []                    None
# 26          []                    None
#
# [27 rows x 22 columns]

# %% [markdown]
# ## Análise de preenchimento

# %%
count_list = [f"COUNTIF({col} IS NOT NULL) / COUNT(*) AS {col}_filled_pct" for col in df_metadata_t1['column_name'].values]
count_list_str = ",\n    ".join(count_list)

query_missingness = f"""
SELECT
    {count_list_str}
FROM 
`basedosdados.{SCHEMA_NAME}.{TABLE}`
"""

df2 = client.query(query_missingness).to_dataframe()
df2_long = df2.T.reset_index()
df2_long.columns = ["field", "value"]
df2_long.sort_values(by="value", ascending=False)
# Out:
#                                          field     value
# 0                               ano_filled_pct  1.000000
# 1                               mes_filled_pct  1.000000
# 2      ano_competencia_movimentacao_filled_pct  1.000000
# 3      mes_competencia_movimentacao_filled_pct  1.000000
# 4                          sigla_uf_filled_pct  1.000000
# 6                      cnae_2_secao_filled_pct  1.000000
# 7                  cnae_2_subclasse_filled_pct  1.000000
# 9                          cbo_2002_filled_pct  1.000000
# 8                saldo_movimentacao_filled_pct  1.000000
# 10                        categoria_filled_pct  1.000000
# 11                   grau_instrucao_filled_pct  1.000000
# 25                origem_informacao_filled_pct  1.000000
# 14                         raca_cor_filled_pct  1.000000
# 16                  tipo_empregador_filled_pct  1.000000
# 15                             sexo_filled_pct  1.000000
# 17             tipo_estabelecimento_filled_pct  1.000000
# 18                tipo_movimentacao_filled_pct  1.000000
# 20  indicador_trabalho_intermitente_filled_pct  1.000000
# 19                 tipo_deficiencia_filled_pct  1.000000
# 26             indicador_fora_prazo_filled_pct  1.000000
# 24               indicador_aprendiz_filled_pct  1.000000
# 21       indicador_trabalho_parcial_filled_pct  1.000000
# 23  tamanho_estabelecimento_janeiro_filled_pct  1.000000
# 12                            idade_filled_pct  0.999558
# 13                horas_contratuais_filled_pct  0.996904
# 22                   salario_mensal_filled_pct  0.990666
# 5                      id_municipio_filled_pct  0.986991

# %% [markdown]
# ## análise de distribuição de valores

# %% [markdown]
# ### Valores Categoricos

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import webbrowser


def get_value_counts(client, table, col):
    query = f"""
    SELECT
        `{col}` AS value,
        COUNT(*) AS freq
    FROM `{table}`
    GROUP BY `{col}`
    ORDER BY freq DESC
    
    """
    df = client.query(query).to_dataframe()
    df["value"] = df["value"].astype(str)  # garante eixo categórico consistente
    return df

dtypes=list(df_metadata_t1['data_type'].values)
columns = list(df_metadata_t1['column_name'].values)

cat_columns=[
    col for col, dtype in zip(columns, dtypes) 
    if dtype in ['STRING',"INT64", 'DATE', 'DATETIME', 'TIMESTAMP']
    ]

table = f"{DATASET_NAME}.{SCHEMA_NAME}.{TABLE}"

# Coleta os value_counts de cada coluna (uma query por coluna)
value_counts_dict = {}
for col in cat_columns:
    print(f"Consultando: {col}")
    value_counts_dict[col] = get_value_counts(client, table, col)

# Monta o grid vertical: 1 gráfico por linha
n = len(cat_columns)
fig = make_subplots(
    rows=n, cols=1,
    subplot_titles=[f"Distribuição: {col}" for col in cat_columns],
    vertical_spacing=0.4 / n  # espaçamento proporcional para não sobrepor títulos
)

for i, col in enumerate(cat_columns, start=1):
    df_vc = value_counts_dict[col]
    fig.add_trace(
        go.Bar(
            x=df_vc["value"],
            y=df_vc["freq"],
            name=col,
            showlegend=False
        ),
        row=i, col=1
    )
    fig.update_xaxes(tickangle=45, row=i, col=1)

# Altura por gráfico ~350px, permitindo scroll vertical no notebook/HTML
fig.update_layout(
    height=350 * n,
    width=1000,
    title_text=f"Distribuição de frequência por variável da tabela '{TABLE}'",
    showlegend=False
)

# Salva como HTML
output_path = os.path.abspath(f"data/outputs/distribuicao_{TABLE}_cat_columns.html")
fig.show()
# Out:
# Consultando: ano
# Consultando: mes
# Consultando: ano_competencia_movimentacao
# Consultando: mes_competencia_movimentacao
# Consultando: sigla_uf
# Consultando: id_municipio
# Consultando: cnae_2_secao
# Consultando: cnae_2_subclasse
# Consultando: saldo_movimentacao
# Consultando: cbo_2002
# Consultando: categoria
# Consultando: grau_instrucao
# Consultando: idade
# Consultando: raca_cor
# Consultando: sexo
# Consultando: tipo_empregador
# Consultando: tipo_estabelecimento
# Consultando: tipo_movimentacao
# Consultando: tipo_deficiencia
# Consultando: indicador_trabalho_intermitente
# Consultando: indicador_trabalho_parcial
# Consultando: tamanho_estabelecimento_janeiro
# Consultando: indicador_aprendiz
# Consultando: origem_informacao
# Consultando: indicador_fora_prazo

# %% [markdown]
# ### Análise colunas numericas

# %%
from scripts.num_dist_vizs import *

# %% [markdown]
# ### Histograma

# %%
N_STDDEV_RANGE = 4
MAX_TICKS = 50
N_BINS = 100  # numero de bins dentro da janela exibida (média ± N_STDDEV_RANGE*σ)
 
dtypes = list(df_metadata_t1['data_type'].values)
columns = list(df_metadata_t1['column_name'].values)
 
num_columns = [
    col for col, dtype in zip(columns, dtypes)
    if dtype in ['FLOAT64']
]
 
table = f"{DATASET_NAME}.{SCHEMA_NAME}.{TABLE}"
 
# Coleta estatísticas e histogramas de cada coluna numérica
histogram_dict, stats_dict, valid_columns, bin_width_dict = collect_stats_and_histograms(
    client, table, num_columns, n_bins=N_BINS
)
 
# Monta o gráfico
fig, valid_columns = build_histogram_figure(
    histogram_dict, stats_dict, bin_width_dict, TABLE,
    n_bins=N_BINS, max_ticks=MAX_TICKS
)

fig.show()
# Out:
# Consultando estatísticas: horas_contratuais
# Consultando histograma: horas_contratuais (bin_width=0.39, janela=[9, 48])
# Consultando estatísticas: salario_mensal
# Consultando histograma: salario_mensal (bin_width=75, janela=[0, 7500])

# %% [markdown]
# ### Distribuição contínua

# %%
N_STDDEV_RANGE = 4
MAX_TICKS = 50
N_BINS = 100000  # numero de bins dentro da janela exibida (média ± N_STDDEV_RANGE*σ)
 
dtypes = list(df_metadata_t1['data_type'].values)
columns = list(df_metadata_t1['column_name'].values)
 
num_columns = [
    col for col, dtype in zip(columns, dtypes)
    if dtype in ['FLOAT64']
]
 
table = f"{DATASET_NAME}.{SCHEMA_NAME}.{TABLE}"
 
# Coleta estatísticas e histogramas de cada coluna numérica
bins_dict, stats_dict, window_dict, valid_columns = collect_stats_and_bins(
    client, table, num_columns, n_bins=200
)

fig, valid_columns = build_density_figure(
    bins_dict, stats_dict, window_dict, TABLE, log_vals=True
)
 
# Salva como HTML e abre no navegador
output_path = os.path.abspath(f"data/outputs/html/distribuicao_{TABLE}_num_columns.html")
fig.show()

# %% [markdown]
# ### Box Plot

# %%
stats_dict, valid_columns = collect_boxplot_stats(client, table, num_columns)

fig, valid_columns = build_boxplot_figure(stats_dict, TABLE, log_vals=False)
output_path = os.path.abspath(f"data/outputs/html/distribuicao_boxplot_{TABLE}_num_columns.html")
fig.show()
# Out:
# Consultando quartis: horas_contratuais
# Consultando quartis: salario_mensal
