# %% [markdown]
# # Exploratory Data Analysis  - CNEFE Addresses

# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path
from pyspark.sql import SparkSession
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="pyspark")

spark = (
    SparkSession.builder.appName("Read Integrated Data")
    .config("spark.driver.memory", "16g")
    .config("spark.executor.memory", "16g")
    .getOrCreate()
)

current_path = os.getcwd()
project_root = Path(current_path).parent.parent
os.chdir(project_root)
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.getcwd()
# Out:
# '/home/lucas-vital/projects/brazilian_address_linkage'

# %% [markdown]
# ## Read Data

# %%
def read_json(path: str | Path):
    with open(path, "r") as f:
        return json.load(f)

# %%
CNEFE_VARS_DICT = read_json("config/dicionario_cnefe.json")
df = spark.read.parquet("data/integrated/integrated_cnefe_addresses.parquet")

# %%
df.groupBy("COD_UNICO_ENDERECO").count().filter("count > 1").orderBy(
    "count", ascending=False
).show(10, False)
# Out:
# [Stage 3:====================================================>    (12 + 1) / 13]
# +------------------+-----+
# |COD_UNICO_ENDERECO|count|
# +------------------+-----+
# |16360870          |6    |
# |211407776         |5    |
# |223042492         |5    |
# |35577467          |5    |
# |1382344           |4    |
# |77000911          |4    |
# |10846066          |4    |
# |22845179          |4    |
# |26445019          |4    |
# |30865597          |4    |
# +------------------+-----+
# only showing top 10 rows

# %%
df.sample(fraction=0.000001).toPandas()
# Out:
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/pyspark/sql/pandas/conversion.py:298: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 26/09/04 07:11:47 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#      COD_UNICO_ENDERECO  COD_UF  COD_MUNICIPIO  COD_DISTRITO  COD_SUBDISTRITO  \
# 0              90795904      29        2927408     292740805      29274080507
# 1             211389698      35        3550308     355030870      35503087000
# 2              30329380      31        3106200     310620005      31062000564
# 3              31591933      31        3106200     310620005      31062000568
# 4             191280447      29        2918001     291800105      29180010500
# ..                  ...     ...            ...           ...              ...
# 111             1404765      11        1100155     110015505      11001550500
# 112           103688035      17        1703008     170300805      17030080500
# 113           182431869      17        1706001     170600105      17060010500
# 114            95896539      41        4103404     410340405      41034040500
# 115             2178989      12        1200708     120070805      12007080500
#
#             COD_SETOR  NUM_QUADRA  NUM_FACE       CEP   DSC_LOCALIDADE  ...  \
# 0    292740805070348P           3         3  40255370           MATATU  ...
# 1    355030870000155P           1         4  02462081           IMIRIM  ...
# 2    310620005640244P           7         2  31140540         SILVEIRA  ...
# 3    310620005680222P           2         3  31360150  SANTA TEREZINHA  ...
# 4    291800105000291P           8         3  45210130        MANDACARU  ...
# ..                ...         ...       ...       ...              ...  ...
# 111  110015505000039P           1         2  76920000         ALVORADA  ...
# 112  170300805000016P           6         1  77870000  BAIRRO DE AREIA  ...
# 113  170600105000017P           0       130  77750000       BELENZINHO  ...
# 114  410340405000006P          22         1  86640000           CENTRO  ...
# 115  120070805000059P           0        39  69930000         SERINGAL  ...
#
#       LATITUDE  LONGITUDE NV_GEO_COORD  COD_ESPECIE DSC_ESTABELECIMENTO  \
# 0   -12.974668 -38.494331            1            1                 NaN
# 1   -23.488943 -46.643614            1            1                 NaN
# 2   -19.891818 -43.929845            1            1                 NaN
# 3   -19.868561 -44.009899            1            6  CIRO CONTABILIDADE
# 4   -13.869847 -40.087576            1            1                 NaN
# ..         ...        ...          ...          ...                 ...
# 111 -10.718612 -62.246147            1            1                 NaN
# 112  -7.193062 -47.777077            1            1                 NaN
# 113  -8.624685 -49.144019            1            1                 NaN
# 114 -22.790492 -51.710885            1            1                 NaN
# 115 -10.854068 -68.293725            1            3          FE EM DEUS
#
#     COD_INDICADOR_ESTAB_ENDERECO COD_INDICADOR_CONST_ENDERECO  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                              1                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 111                          NaN                          NaN
# 112                          NaN                          NaN
# 113                          NaN                          NaN
# 114                          NaN                          NaN
# 115                            1                          NaN
#
#     COD_INDICADOR_FINALIDADE_CONST COD_TIPO_ESPECI  UF
# 0                              NaN           101.0  BA
# 1                              NaN           101.0  SP
# 2                              NaN           103.0  MG
# 3                              NaN             NaN  MG
# 4                              NaN           101.0  BA
# ..                             ...             ...  ..
# 111                            NaN           101.0  RO
# 112                            NaN           101.0  TO
# 113                            NaN           101.0  TO
# 114                            NaN           101.0  PR
# 115                            NaN             NaN  AC
#
# [116 rows x 35 columns]

# %% [markdown]
# ## analyse missingness

# %%
from pyspark.sql import functions as F

total_rows = df.count()

fulfillment_exprs = [
    F.struct(
        F.lit(c).alias("column"),
        (F.count(F.col(c)) / F.lit(total_rows) * 100).alias("fulfillment_pct"),
    )
    for c in df.columns
]

result = (
    df.select(F.array(*fulfillment_exprs).alias("stats"))
    .selectExpr("explode(stats) as stats")
    .select("stats.column", "stats.fulfillment_pct")
)

result.orderBy(F.col("fulfillment_pct").desc()).show(
    df.columns.__len__(), truncate=False
)
# Out:
# [Stage 8:=======================================================> (38 + 1) / 39]
# +------------------------------+--------------------+
# |column                        |fulfillment_pct     |
# +------------------------------+--------------------+
# |COD_UNICO_ENDERECO            |100.0               |
# |COD_UF                        |100.0               |
# |COD_MUNICIPIO                 |100.0               |
# |COD_DISTRITO                  |100.0               |
# |COD_SUBDISTRITO               |100.0               |
# |COD_SETOR                     |100.0               |
# |NUM_QUADRA                    |100.0               |
# |NUM_FACE                      |100.0               |
# |CEP                           |100.0               |
# |NOM_TIPO_SEGLOGR              |100.0               |
# |NOM_SEGLOGR                   |100.0               |
# |NUM_ENDERECO                  |100.0               |
# |LATITUDE                      |100.0               |
# |LONGITUDE                     |100.0               |
# |NV_GEO_COORD                  |100.0               |
# |COD_ESPECIE                   |100.0               |
# |UF                            |100.0               |
# |DSC_LOCALIDADE                |99.99999639973312   |
# |COD_TIPO_ESPECI               |81.6401753779999    |
# |NOM_COMP_ELEM1                |40.39532100316936   |
# |DSC_MODIFICADOR               |34.417924828677926  |
# |VAL_COMP_ELEM1                |29.455516790182074  |
# |COD_INDICADOR_ESTAB_ENDERECO  |15.180140927946283  |
# |NOM_TITULO_SEGLOGR            |14.017390639081123  |
# |DSC_ESTABELECIMENTO           |13.632778629715927  |
# |NOM_COMP_ELEM2                |10.680500392091563  |
# |VAL_COMP_ELEM2                |9.525702192675032   |
# |COD_INDICADOR_CONST_ENDERECO  |3.2244935155818424  |
# |COD_INDICADOR_FINALIDADE_CONST|3.215004112179815   |
# |NOM_COMP_ELEM3                |2.207196708456014   |
# |VAL_COMP_ELEM3                |1.9215452345405104  |
# |NOM_COMP_ELEM4                |0.22597795061558937 |
# |VAL_COMP_ELEM4                |0.18427335926275534 |
# |NOM_COMP_ELEM5                |0.022345956394017708|
# |VAL_COMP_ELEM5                |0.020384711016704114|
# +------------------------------+--------------------+

# %% [markdown]
# ## análise Contagem valores dos campos

# %%
for c in df.columns:
    print(f"Column: {c}")
    df.filter(F.col(c).isNotNull()).groupBy(c).count().orderBy(
        F.col("count").desc()
    ).show(100, truncate=False)
# Out:
# Column: COD_UNICO_ENDERECO
# +------------------+-----+
# |COD_UNICO_ENDERECO|count|
# +------------------+-----+
# |16360870          |6    |
# |35577467          |5    |
# |211407776         |5    |
# |223042492         |5    |
# |431787            |4    |
# |6034064           |4    |
# |28138586          |4    |
# |32354636          |4    |
# |39214224          |4    |
# |57507653          |4    |
# |59051025          |4    |
# |73516017          |4    |
# |112749007         |4    |
# |193840649         |4    |
# |194154002         |4    |
# |194767768         |4    |
# |205386884         |4    |
# |206736177         |4    |
# |14578679          |4    |
# |29618481          |4    |
# |38039397          |4    |
# |47152822          |4    |
# |49455701          |4    |
# |52543956          |4    |
# |77000278          |4    |
# |93645838          |4    |
# |97967158          |4    |
# |98174303          |4    |
# |110800014         |4    |
# |192351829         |4    |
# |193230119         |4    |
# |1382344           |4    |
# |10846066          |4    |
# |22845179          |4    |
# |26445019          |4    |
# |30865597          |4    |
# |40303755          |4    |
# |40506535          |4    |
# |52544128          |4    |
# |54235308          |4    |
# |55105398          |4    |
# |77000911          |4    |
# |99234612          |4    |
# |106071583         |4    |
# |191900198         |4    |
# |211036524         |4    |
# |1071739           |4    |
# |10813973          |4    |
# |41032695          |4    |
# |58681130          |4    |
# |76231484          |4    |
# |88451351          |4    |
# |92451405          |4    |
# |110253575         |4    |
# |110890017         |4    |
# |111498341         |4    |
# |113376268         |4    |
# |180469720         |4    |
# |196027767         |4    |
# |206000359         |4    |
# |211069589         |4    |
# |212166536         |4    |
# |18687279          |4    |
# |24077362          |4    |
# |42653937          |4    |
# |47152406          |4    |
# |54235106          |4    |
# |67847416          |4    |
# |76852544          |4    |
# |79735954          |4    |
# |95159446          |4    |
# |182545100         |4    |
# |200374522         |4    |
# |205824382         |4    |
# |208124616         |4    |
# |208125027         |4    |
# |212982183         |4    |
# |33168411          |4    |
# |47952734          |4    |
# |49455699          |4    |
# |57701167          |4    |
# |58733606          |4    |
# |80849539          |4    |
# |95990777          |4    |
# |101624147         |4    |
# |110740666         |4    |
# |112939435         |4    |
# |186971202         |4    |
# |209643509         |4    |
# |13435661          |4    |
# |22729200          |4    |
# |32248526          |4    |
# |36256043          |4    |
# |40460757          |4    |
# |50088637          |4    |
# |63768414          |4    |
# |69139370          |4    |
# |79715902          |4    |
# |108297619         |4    |
# |109695264         |4    |
# +------------------+-----+
# only showing top 100 rows
# Column: COD_UF
# +------+--------+
# |COD_UF|count   |
# +------+--------+
# |35    |22953725|
# |31    |12038190|
# |29    |9047296 |
# |33    |8962200 |
# |43    |6456747 |
# |41    |6122025 |
# |26    |5120482 |
# |23    |4750642 |
# |42    |4181139 |
# |52    |3960937 |
# |15    |3911170 |
# |21    |3257843 |
# |25    |2228886 |
# |32    |2221348 |
# |51    |1985314 |
# |22    |1891421 |
# |24    |1845003 |
# |13    |1658970 |
# |27    |1626565 |
# |50    |1507819 |
# |53    |1318887 |
# |28    |1258755 |
# |11    |965370  |
# |17    |848437  |
# |12    |410524  |
# |16    |312665  |
# |14    |260515  |
# +------+--------+
#
# Column: COD_MUNICIPIO
# +-------------+-------+
# |COD_MUNICIPIO|count  |
# +-------------+-------+
# |3550308      |5689391|
# |3304557      |3276028|
# |2927408      |1390897|
# |5300108      |1318887|
# |2304400      |1193529|
# |3106200      |1180102|
# |4106902      |900459 |
# |1302603      |878488 |
# |5208707      |777018 |
# |4314902      |762239 |
# |2611606      |737511 |
# |1501402      |618075 |
# |3518800      |596864 |
# |3509502      |574086 |
# |2111300      |481179 |
# |3304904      |479498 |
# |2704302      |466514 |
# |5002704      |462591 |
# |2507507      |426733 |
# |3301702      |425338 |
# |3303500      |416521 |
# |2211001      |415723 |
# |2408102      |395998 |
# |3170206      |393239 |
# |3543402      |376780 |
# |3548708      |374870 |
# |3547809      |369250 |
# |2910800      |359076 |
# |3552205      |355399 |
# |2607901      |339991 |
# |3534401      |328129 |
# |5103403      |326051 |
# |3549904      |320850 |
# |3118601      |317439 |
# |4205407      |313343 |
# |3136702      |307905 |
# |2800308      |307745 |
# |4113700      |283015 |
# |3301009      |281500 |
# |4209102      |280866 |
# |3541000      |279872 |
# |3205002      |265504 |
# |3549805      |258549 |
# |3303302      |254466 |
# |5201405      |253245 |
# |4305108      |250940 |
# |1100205      |248375 |
# |3205200      |245792 |
# |3300456      |233172 |
# |3548500      |231082 |
# |3538709      |224750 |
# |2604106      |221349 |
# |3143302      |220712 |
# |1500800      |220206 |
# |2905701      |216243 |
# |2504009      |215660 |
# |3530607      |214936 |
# |4115200      |209669 |
# |3106705      |209615 |
# |3525904      |207882 |
# |5201108      |207750 |
# |3305109      |202871 |
# |2611101      |201233 |
# |3506003      |200245 |
# |2933307      |199847 |
# |3529401      |195094 |
# |4314407      |191829 |
# |2303709      |186865 |
# |3300704      |185612 |
# |3513801      |185596 |
# |3170107      |183595 |
# |3516200      |182010 |
# |1600303      |181649 |
# |3201308      |180922 |
# |3518701      |180594 |
# |2610707      |178741 |
# |4119905      |178567 |
# |1200401      |177995 |
# |4304606      |176899 |
# |2609600      |175665 |
# |4202404      |175212 |
# |4104808      |173915 |
# |3510609      |170474 |
# |3205309      |167624 |
# |3551009      |165050 |
# |3523107      |162210 |
# |3154606      |159764 |
# |3303906      |159371 |
# |1400100      |158533 |
# |4125506      |157882 |
# |3554102      |154952 |
# |1721000      |151741 |
# |3127701      |150898 |
# |3526902      |150450 |
# |4316907      |149483 |
# |3302403      |149212 |
# |5108402      |147725 |
# |2408003      |146770 |
# |1506807      |146496 |
# |3552502      |143542 |
# +-------------+-------+
# only showing top 100 rows
# Column: COD_DISTRITO
# +------------+-------+
# |COD_DISTRITO|count  |
# +------------+-------+
# |330455705   |3276028|
# |292740805   |1390897|
# |530010805   |1318887|
# |230440005   |1193529|
# |410690205   |900459 |
# |130260305   |878488 |
# |520870705   |775706 |
# |431490205   |762239 |
# |261160605   |737511 |
# |310620005   |726983 |
# |350950205   |515772 |
# |211130005   |481179 |
# |270430205   |466514 |
# |500270405   |457559 |
# |250750705   |426733 |
# |330350005   |416521 |
# |221100105   |415723 |
# |240810205   |395998 |
# |351880005   |387294 |
# |317020605   |377919 |
# |354340205   |360289 |
# |354870805   |359628 |
# |355220505   |355399 |
# |353440105   |328129 |
# |310620060   |319313 |
# |354780905   |318929 |
# |291080005   |315081 |
# |280030805   |307745 |
# |313670205   |300155 |
# |354990405   |278596 |
# |411370005   |272949 |
# |420910205   |269751 |
# |330330205   |254466 |
# |430510805   |240187 |
# |354980505   |237406 |
# |330045605   |233172 |
# |354850005   |231082 |
# |150080005   |220206 |
# |110020505   |217899 |
# |311860105   |209850 |
# |310670505   |209615 |
# |351880010   |209570 |
# |314330205   |209199 |
# |352590405   |207882 |
# |330100905   |207670 |
# |354100005   |206098 |
# |411520005   |204872 |
# |520110805   |203530 |
# |250400905   |202469 |
# |260410605   |201903 |
# |350600305   |199387 |
# |352940105   |195094 |
# |260790105   |188133 |
# |510340310   |187205 |
# |351380105   |185596 |
# |317010705   |183595 |
# |353870905   |182831 |
# |351620005   |182010 |
# |261070705   |178741 |
# |431440705   |178073 |
# |120040105   |177995 |
# |430460605   |176899 |
# |355030830   |176366 |
# |260960005   |175665 |
# |261110105   |173663 |
# |293330705   |171568 |
# |411990505   |171372 |
# |160030305   |168747 |
# |355100905   |165050 |
# |352310705   |162210 |
# |410480805   |162091 |
# |320500215   |159516 |
# |330170205   |159100 |
# |140010005   |158533 |
# |412550605   |157789 |
# |520140510   |157770 |
# |330490405   |156052 |
# |420240405   |151119 |
# |352690205   |150450 |
# |330170210   |150217 |
# |420540705   |148397 |
# |172100005   |147483 |
# |240800305   |146770 |
# |355030843   |143330 |
# |312770105   |139951 |
# |210530205   |139663 |
# |431690705   |138664 |
# |330240305   |137461 |
# |410830405   |136358 |
# |230730405   |134162 |
# |330630505   |133905 |
# |310620025   |133806 |
# |150420805   |133020 |
# |510340305   |129179 |
# |355410205   |128550 |
# |150553605   |128238 |
# |150680705   |127531 |
# |355280905   |125967 |
# |431340905   |125611 |
# |150140245   |125319 |
# +------------+-------+
# only showing top 100 rows
# Column: COD_SUBDISTRITO
# +---------------+------+
# |COD_SUBDISTRITO|count |
# +---------------+------+
# |43149020500    |762239|
# |35095020500    |515772|
# |21113000500    |481179|
# |25075070500    |426733|
# |35188000500    |387294|
# |31702060500    |377919|
# |35434020500    |360289|
# |35487080500    |359628|
# |35522050500    |355399|
# |33045570521    |333230|
# |35344010500    |328129|
# |35478090500    |318929|
# |28003080500    |307745|
# |33045570523    |305095|
# |35499040500    |278596|
# |42091020500    |269751|
# |33033020500    |254466|
# |35498050500    |237406|
# |35485000500    |231082|
# |13026030512    |227665|
# |29274080522    |224957|
# |15008000500    |220206|
# |33045570524    |219994|
# |33045570529    |217627|
# |35188001000    |209570|
# |31433020500    |209199|
# |29274080518    |208721|
# |35259040500    |207882|
# |35410000500    |206098|
# |52011080500    |203530|
# |25040090500    |202469|
# |26041060500    |201903|
# |35060030500    |199387|
# |35294010500    |195094|
# |33045570517    |192472|
# |33045570522    |191472|
# |26116060523    |188308|
# |26079010500    |188133|
# |35138010500    |185596|
# |31701070500    |183595|
# |35387090500    |182831|
# |35162000500    |182010|
# |26107070500    |178741|
# |12004010500    |177995|
# |43046060500    |176899|
# |35503083000    |176366|
# |26096000500    |175665|
# |29333070500    |171568|
# |41199050500    |171372|
# |16003030500    |168747|
# |35510090500    |165050|
# |33045570520    |164695|
# |35231070500    |162210|
# |41048080500    |162091|
# |32050021500    |159516|
# |33017020500    |159100|
# |14001000500    |158533|
# |41255060500    |157789|
# |52014051000    |157770|
# |31062000562    |157709|
# |33049040500    |156052|
# |31062000567    |154885|
# |42024040500    |151119|
# |35269020500    |150450|
# |33017021000    |150217|
# |42054070500    |148397|
# |17210000500    |147483|
# |41069020501    |147114|
# |24080030500    |146770|
# |26116060520    |143992|
# |35503084300    |143330|
# |26116060521    |140083|
# |31277010500    |139951|
# |21053020500    |139663|
# |13026030514    |138616|
# |29274080506    |137757|
# |24081020506    |137412|
# |53001080515    |137151|
# |41083040500    |136358|
# |23073040500    |134162|
# |33063050500    |133905|
# |31062002561    |133412|
# |15042080500    |133020|
# |23044000518    |129062|
# |27043020512    |128696|
# |35541020500    |128550|
# |15055360500    |128238|
# |23044000515    |127923|
# |33045570509    |127735|
# |15068070500    |127531|
# |31062000565    |127410|
# |35528090500    |125967|
# |43134090500    |125611|
# |15014024500    |125319|
# |35503086800    |125298|
# |24032510500    |125038|
# |35016080500    |124546|
# |23044000514    |124136|
# |41069020504    |124130|
# |31223060500    |123994|
# +---------------+------+
# only showing top 100 rows
# Column: COD_SETOR
# +----------------+-----+
# |COD_SETOR       |count|
# +----------------+-----+
# |530010805380078P|6495 |
# |430463005000020P|2787 |
# |530010805060458P|2734 |
# |330190005000198P|2658 |
# |351500405000339P|2338 |
# |430310305000245P|2296 |
# |290570110000058P|2269 |
# |292530310000024P|2225 |
# |430460605000588P|2193 |
# |291080015000025P|2125 |
# |290070205000158P|2074 |
# |291955305000137P|2070 |
# |351907105000343P|1991 |
# |430460605000076P|1950 |
# |420820305000141P|1944 |
# |230440005180085P|1888 |
# |292530305000164P|1854 |
# |410040005000076P|1848 |
# |292550105000049P|1839 |
# |291840705000282P|1839 |
# |110030405000040P|1818 |
# |355220505001011P|1813 |
# |261160605180086P|1789 |
# |330455705360202P|1785 |
# |410960905000021P|1739 |
# |330455705390097P|1732 |
# |291080005110228P|1710 |
# |430770805100036P|1694 |
# |530010805150174P|1693 |
# |510700810000016P|1691 |
# |351907105000128P|1688 |
# |230440005160271P|1682 |
# |430463005000069P|1664 |
# |230428505000035P|1649 |
# |522185805000333P|1643 |
# |270430205070106P|1642 |
# |430463005000034P|1634 |
# |351907105000384P|1634 |
# |292335705000048P|1630 |
# |410765205000180P|1629 |
# |430460605000609P|1622 |
# |240800305000426P|1619 |
# |230440005200136P|1618 |
# |430463005000011P|1610 |
# |520450805000073P|1609 |
# |430463007000020P|1577 |
# |353760205000229P|1573 |
# |432380405000018P|1572 |
# |292575805000005P|1571 |
# |291360610000031P|1564 |
# |261070705000592P|1553 |
# |240360805000111P|1550 |
# |420210705000011P|1541 |
# |292550110000034P|1539 |
# |291080005060243P|1537 |
# |411990505000666P|1536 |
# |421190005000181P|1533 |
# |431440705180112P|1532 |
# |530010805160108P|1531 |
# |350570805000271P|1529 |
# |260790105000555P|1524 |
# |130260305080293P|1522 |
# |410420405000140P|1521 |
# |130260305130161P|1506 |
# |350635905000375P|1504 |
# |352220805000081P|1503 |
# |355030869000043P|1498 |
# |292770505000002P|1495 |
# |421660213000109P|1492 |
# |292740805260244P|1490 |
# |430990205000001P|1481 |
# |230440005130004P|1477 |
# |210540105000106P|1463 |
# |110012205000200P|1457 |
# |355220505001021P|1454 |
# |150510605000109P|1451 |
# |240820105000061P|1450 |
# |230440005130003P|1441 |
# |291360645000025P|1439 |
# |320240505000308P|1439 |
# |110020505000170P|1437 |
# |522185805000312P|1435 |
# |261070705000340P|1433 |
# |353440105000034P|1431 |
# |291955305000151P|1426 |
# |510840220000090P|1424 |
# |354140605000370P|1415 |
# |355030810000122P|1413 |
# |292070005000042P|1412 |
# |430460605000385P|1411 |
# |354730405000128P|1409 |
# |330455705240635P|1404 |
# |110020505000036P|1402 |
# |150680705000409P|1398 |
# |312570505000033P|1396 |
# |293050105000153P|1392 |
# |110013005000052P|1384 |
# |261160605210439P|1380 |
# |291050315000016P|1380 |
# |432380425000006P|1376 |
# +----------------+-----+
# only showing top 100 rows
# Column: NUM_QUADRA
# +----------+--------+
# |NUM_QUADRA|count   |
# +----------+--------+
# |1         |23473364|
# |0         |16653474|
# |2         |11900144|
# |3         |9274118 |
# |4         |7523599 |
# |5         |6173052 |
# |6         |5130591 |
# |7         |4243974 |
# |8         |3575301 |
# |9         |3007168 |
# |10        |2536643 |
# |11        |2134530 |
# |12        |1831619 |
# |13        |1576149 |
# |14        |1338595 |
# |15        |1152666 |
# |16        |1000758 |
# |17        |865536  |
# |18        |759207  |
# |19        |656548  |
# |20        |589824  |
# |21        |518946  |
# |22        |450432  |
# |23        |405497  |
# |24        |361156  |
# |25        |319958  |
# |26        |283566  |
# |27        |258865  |
# |28        |230133  |
# |29        |206970  |
# |30        |188881  |
# |31        |171342  |
# |32        |155413  |
# |33        |142052  |
# |34        |127034  |
# |35        |114262  |
# |36        |105374  |
# |37        |96929   |
# |38        |90544   |
# |39        |84572   |
# |40        |75346   |
# |41        |68156   |
# |42        |63806   |
# |43        |59311   |
# |100       |56008   |
# |44        |54492   |
# |45        |50024   |
# |46        |47124   |
# |47        |44054   |
# |49        |40142   |
# |48        |39587   |
# |200       |39475   |
# |50        |36642   |
# |51        |33704   |
# |52        |32219   |
# |53        |28835   |
# |55        |27356   |
# |54        |27195   |
# |56        |25048   |
# |57        |23332   |
# |58        |22423   |
# |59        |19614   |
# |60        |19502   |
# |62        |18200   |
# |61        |17087   |
# |300       |16478   |
# |63        |15048   |
# |65        |14905   |
# |64        |14679   |
# |66        |13616   |
# |67        |12181   |
# |68        |10625   |
# |70        |10531   |
# |69        |10276   |
# |72        |9897    |
# |101       |9737    |
# |71        |9681    |
# |73        |9563    |
# |400       |9118    |
# |201       |8517    |
# |75        |8452    |
# |74        |8422    |
# |76        |7420    |
# |77        |6703    |
# |78        |6654    |
# |79        |6589    |
# |80        |6454    |
# |81        |6191    |
# |82        |5552    |
# |84        |5522    |
# |83        |5275    |
# |85        |4831    |
# |86        |4604    |
# |88        |4599    |
# |87        |4531    |
# |90        |3923    |
# |91        |3909    |
# |89        |3774    |
# |102       |3614    |
# |93        |3585    |
# +----------+--------+
# only showing top 100 rows
# Column: NUM_FACE
# +--------+--------+
# |NUM_FACE|count   |
# +--------+--------+
# |1       |25857620|
# |2       |20784844|
# |3       |18991681|
# |4       |16085274|
# |5       |4049027 |
# |6       |2893507 |
# |7       |2294157 |
# |8       |1727192 |
# |9       |1382357 |
# |10      |1153187 |
# |11      |950289  |
# |12      |818571  |
# |13      |696034  |
# |14      |606098  |
# |15      |533094  |
# |16      |467204  |
# |17      |405637  |
# |18      |367569  |
# |19      |337326  |
# |20      |302136  |
# |21      |279535  |
# |22      |258644  |
# |23      |237452  |
# |24      |218900  |
# |25      |201600  |
# |26      |189199  |
# |27      |178575  |
# |28      |170911  |
# |29      |158514  |
# |30      |152376  |
# |31      |143245  |
# |32      |136748  |
# |33      |131211  |
# |34      |127763  |
# |35      |124684  |
# |36      |116279  |
# |37      |110772  |
# |38      |110047  |
# |40      |105808  |
# |39      |103891  |
# |41      |100340  |
# |43      |96527   |
# |42      |96423   |
# |44      |96185   |
# |46      |92407   |
# |45      |91498   |
# |47      |90443   |
# |48      |89262   |
# |49      |87486   |
# |50      |84288   |
# |51      |83906   |
# |52      |82817   |
# |53      |82093   |
# |55      |81509   |
# |54      |80468   |
# |59      |78085   |
# |56      |77712   |
# |58      |76920   |
# |57      |75484   |
# |61      |75412   |
# |64      |74936   |
# |62      |74733   |
# |63      |73977   |
# |60      |73875   |
# |65      |73392   |
# |68      |72988   |
# |66      |70920   |
# |70      |70885   |
# |69      |69739   |
# |71      |69708   |
# |75      |68097   |
# |67      |67752   |
# |74      |66925   |
# |73      |66467   |
# |72      |65191   |
# |78      |65113   |
# |76      |64179   |
# |77      |61562   |
# |81      |61551   |
# |83      |61533   |
# |79      |61414   |
# |84      |60994   |
# |80      |60299   |
# |82      |59776   |
# |85      |57936   |
# |87      |56931   |
# |86      |56443   |
# |89      |55239   |
# |90      |54674   |
# |94      |54529   |
# |95      |54179   |
# |88      |53931   |
# |92      |53901   |
# |93      |53579   |
# |91      |53344   |
# |96      |52610   |
# |98      |50054   |
# |102     |49721   |
# |97      |49238   |
# |100     |49051   |
# +--------+--------+
# only showing top 100 rows
# Column: CEP
# +--------+------+
# |CEP     |count |
# +--------+------+
# |68515000|127985|
# |65110000|118306|
# |11740000|104824|
# |45810000|83012 |
# |43700000|68062 |
# |68440000|67560 |
# |95555000|65672 |
# |11730000|61564 |
# |49400000|61320 |
# |45400000|60589 |
# |68400000|59096 |
# |88220000|58160 |
# |65130000|57514 |
# |56280000|56229 |
# |46430000|56077 |
# |18150000|55422 |
# |44700000|55253 |
# |65930000|55235 |
# |28300000|54937 |
# |95590000|54852 |
# |44470000|52635 |
# |65400000|51985 |
# |48700000|51978 |
# |68600000|51780 |
# |61700000|51622 |
# |83260000|49051 |
# |65700000|47756 |
# |44790000|47492 |
# |65950000|47105 |
# |55900000|46746 |
# |48730000|46617 |
# |65800000|45899 |
# |98700000|45359 |
# |28230000|45230 |
# |55590000|44626 |
# |55000990|44544 |
# |56200000|44317 |
# |57100000|43952 |
# |42850000|43795 |
# |68450000|43215 |
# |62700000|43103 |
# |89240000|43078 |
# |44600000|43002 |
# |63800000|42207 |
# |49100000|42114 |
# |69090000|41905 |
# |83255000|41020 |
# |48970000|40902 |
# |83280000|40792 |
# |59570000|40619 |
# |49200000|40551 |
# |48800000|40360 |
# |78850000|40076 |
# |69980000|40026 |
# |48500000|39763 |
# |55660000|39758 |
# |65500000|39004 |
# |95800000|38993 |
# |65200000|38676 |
# |46880000|37816 |
# |54590000|37780 |
# |28200000|37758 |
# |68380000|37410 |
# |65940000|37185 |
# |47300000|37101 |
# |59575000|36883 |
# |55200000|36575 |
# |48400000|36568 |
# |58900000|36509 |
# |68800000|36444 |
# |95560000|36407 |
# |55750000|36356 |
# |68473000|36337 |
# |88780000|36209 |
# |65590000|36128 |
# |77500000|36098 |
# |39480000|35845 |
# |44380000|35770 |
# |62870000|35724 |
# |96600000|35719 |
# |47600000|35620 |
# |45836000|35466 |
# |95625000|35109 |
# |63660000|35012 |
# |64260000|34531 |
# |69415000|34498 |
# |56000000|34322 |
# |18170000|34154 |
# |48280000|34147 |
# |44200000|34084 |
# |68220000|34025 |
# |57160000|33836 |
# |59300000|33782 |
# |68445000|33752 |
# |68790000|33536 |
# |69099000|33494 |
# |88390000|33480 |
# |45700000|33473 |
# |62930000|33441 |
# |48760000|33283 |
# +--------+------+
# only showing top 100 rows
# Column: DSC_LOCALIDADE
# +-----------------------------+--------+
# |DSC_LOCALIDADE               |count   |
# +-----------------------------+--------+
# |CENTRO                       |11033180|
# |BELA VISTA                   |506768  |
# |SANTO ANTONIO                |418066  |
# |BOA VISTA                    |377241  |
# |VILA NOVA                    |329992  |
# |SAO JOSE                     |323602  |
# |CIDADE NOVA                  |294550  |
# |ZONA RURAL                   |288680  |
# |SAO FRANCISCO                |287112  |
# |SANTA CRUZ                   |259483  |
# |CAMPO GRANDE                 |253315  |
# |NOVO HORIZONTE               |227416  |
# |SAO CRISTOVAO                |217529  |
# |PLANALTO                     |195502  |
# |SAO SEBASTIAO                |190420  |
# |SANTA MARIA                  |189940  |
# |SAO JOAO                     |183719  |
# |JARDIM AMERICA               |183054  |
# |SANTA TEREZINHA              |175454  |
# |SANTA LUZIA                  |174709  |
# |SAO PEDRO                    |164414  |
# |SANTANA                      |163563  |
# |LIBERDADE                    |149731  |
# |SANTA RITA                   |145688  |
# |CEILANDIA                    |142343  |
# |NOVA ESPERANCA               |141924  |
# |COHAB                        |136958  |
# |IPIRANGA                     |136513  |
# |JARDIM PRIMAVERA             |133015  |
# |ALVORADA                     |131584  |
# |SAO MIGUEL                   |130358  |
# |JARDIM PAULISTA              |130289  |
# |CRUZEIRO                     |119893  |
# |AEROPORTO                    |118999  |
# |FLORESTA                     |117128  |
# |SANTA ROSA                   |115791  |
# |BOM JESUS                    |112499  |
# |BOQUEIRAO                    |110758  |
# |SAO PAULO                    |109111  |
# |NOSSA SENHORA DE FATIMA      |107849  |
# |JARDIM ALVORADA              |107049  |
# |AGUAS CLARAS                 |106350  |
# |BOA ESPERANCA                |103368  |
# |JARDIM BELA VISTA            |102124  |
# |SAO JORGE                    |102019  |
# |JABAQUARA                    |100925  |
# |PETROPOLIS                   |100453  |
# |SAO DOMINGOS                 |99878   |
# |VISTA ALEGRE                 |99734   |
# |SANTA CECILIA                |98720   |
# |ELDORADO                     |97620   |
# |VILA MARIANA                 |97603   |
# |PRIMAVERA                    |97260   |
# |COPACABANA                   |96534   |
# |PENHA                        |96460   |
# |NOSSA SENHORA APARECIDA      |96354   |
# |SAO BENEDITO                 |95416   |
# |CIDADE JARDIM                |93402   |
# |SAO GERALDO                  |92981   |
# |TIJUCA                       |91350   |
# |SANTOS DUMONT                |91223   |
# |JARAGUA                      |88978   |
# |FATIMA                       |88679   |
# |CONCEICAO                    |87771   |
# |SANTA TEREZA                 |87289   |
# |BANGU                        |86284   |
# |OLARIA                       |85938   |
# |BOM JARDIM                   |84335   |
# |SAO VICENTE                  |84047   |
# |SANTA MONICA                 |83819   |
# |JARDIM EUROPA                |83118   |
# |ITAIM PAULISTA               |82971   |
# |BRASILANDIA                  |82059   |
# |CIDADE INDUSTRIAL DE CURITIBA|81657   |
# |REALENGO                     |80532   |
# |VARZEA                       |80196   |
# |NOSSA SENHORA DAS GRACAS     |78833   |
# |INDUSTRIAL                   |78698   |
# |BONSUCESSO                   |78143   |
# |PARAISO                      |78126   |
# |TANCREDO NEVES               |77826   |
# |VILA MARIA                   |77726   |
# |TAGUATINGA                   |76345   |
# |VILA SONIA                   |75984   |
# |SAUDE                        |75160   |
# |JARDIM PARAISO               |74675   |
# |BARRA DA TIJUCA              |74582   |
# |BOA VIAGEM                   |74503   |
# |BOTAFOGO                     |73597   |
# |LARANJEIRAS                  |73378   |
# |APARECIDA                    |73350   |
# |NOVA BRASILIA                |72946   |
# |MANGABEIRA                   |72902   |
# |ALTO DA BOA VISTA            |72755   |
# |BRASILIA                     |72640   |
# |INDEPENDENCIA                |72601   |
# |PINHEIROS                    |72561   |
# |BOM RETIRO                   |72508   |
# |VILA RICA                    |71796   |
# |CIDADE UNIVERSITARIA         |69707   |
# +-----------------------------+--------+
# only showing top 100 rows
# Column: NOM_TIPO_SEGLOGR
# +------------------+--------+
# |NOM_TIPO_SEGLOGR  |count   |
# +------------------+--------+
# |RUA               |73490113|
# |AVENIDA           |10892816|
# |ESTRADA           |8373546 |
# |TRAVESSA          |3079213 |
# |RODOVIA           |1788239 |
# |FAZENDA           |1591557 |
# |SITIO             |1456285 |
# |EDF               |1266971 |
# |POVOADO           |898250  |
# |ALAMEDA           |777059  |
# |BECO              |529601  |
# |PRACA             |449158  |
# |LINHA             |418688  |
# |CORREGO           |390731  |
# |RAMAL             |364631  |
# |RIO               |319863  |
# |COMUNIDADE        |306983  |
# |VIELA             |300486  |
# |PASSAGEM          |284718  |
# |VILA              |278385  |
# |CAMINHO           |249157  |
# |ASSENTAMENTO      |232467  |
# |ACESSO            |227100  |
# |VICINAL           |180682  |
# |SERVIDAO          |154357  |
# |QUADRA            |142901  |
# |ENTRADA           |130819  |
# |VIA               |124340  |
# |BAIRRO            |110837  |
# |CONDOMINIO        |107146  |
# |LOTEAMENTO        |104168  |
# |TRAVESSAO         |103701  |
# |REGIAO            |75545   |
# |CHACARA           |73697   |
# |CORREDOR          |72809   |
# |CONJUNTO          |69902   |
# |LUGAREJO          |69787   |
# |IGARAPE           |64598   |
# |ALDEIA            |64255   |
# |ENGENHO           |62576   |
# |AGLOMERADO        |56045   |
# |1A TRAVESSA DA RUA|53304   |
# |SERRA             |49985   |
# |2A TRAVESSA DA RUA|45489   |
# |LADEIRA           |38643   |
# |RESIDENCIAL       |36554   |
# |ESCADARIA         |35462   |
# |AGROVILA          |34991   |
# |ESTRADA MUNICIPAL |34921   |
# |LAGO              |32586   |
# |ILHA              |29828   |
# |OUTROS            |28041   |
# |FOLHA             |28041   |
# |2A TRAVESSA       |26354   |
# |PRAIA             |24251   |
# |LARGO             |24156   |
# |1A TRAVESSA       |23243   |
# |3A TRAVESSA DA RUA|20067   |
# |VILAREJO          |19721   |
# |SETOR             |19688   |
# |ALTO              |18172   |
# |LAGOA             |17765   |
# |PASSARELA         |17364   |
# |PROLONGAMENTO     |17293   |
# |MARGEM            |16274   |
# |RIBEIRAO          |15851   |
# |FURO              |15489   |
# |DISTRITO          |13980   |
# |PROPRIEDADE       |13980   |
# |SAIDA             |13776   |
# |3A TRAVESSA       |13689   |
# |SEDE              |13658   |
# |AREA              |13368   |
# |PROJETADA         |12342   |
# |ACAMPAMENTO       |12080   |
# |COLONIA           |11964   |
# |ZONA              |11539   |
# |MARGINAL          |11033   |
# |LOTE              |10634   |
# |PASSEIO           |10384   |
# |PROJETO           |10194   |
# |BARRA             |9966    |
# |TRAVESSIA         |9815    |
# |RUELA             |9269    |
# |BEIRA             |9147    |
# |RIACHO            |9118    |
# |4A TRAVESSA DA RUA|9101    |
# |ESTANCIA          |9044    |
# |MORRO             |8488    |
# |ESCADAO           |8339    |
# |4A TRAVESSA       |7998    |
# |CENTRO            |7990    |
# |CAMPO             |7907    |
# |RANCHO            |7639    |
# |CABECEIRA         |7589    |
# |PONTE             |7242    |
# |BAIXA             |6844    |
# |EIXO              |6786    |
# |NUCLEO            |6465    |
# |PARQUE            |6403    |
# +------------------+--------+
# only showing top 100 rows
# Column: NOM_TITULO_SEGLOGR
# +------------------+-------+
# |NOM_TITULO_SEGLOGR|count  |
# +------------------+-------+
# |SAO               |2396878|
# |DOUTOR            |1715110|
# |SANTA             |1081140|
# |PADRE             |658554 |
# |CORONEL           |652417 |
# |PROFESSOR         |650080 |
# |PRESIDENTE        |542516 |
# |VEREADOR          |456241 |
# |SANTO             |449027 |
# |DOM               |416703 |
# |NOSSA SENHORA     |394948 |
# |MARECHAL          |353017 |
# |GENERAL           |337653 |
# |BARAO             |291695 |
# |PROFESSORA        |288810 |
# |DONA              |264235 |
# |CAPITAO           |255762 |
# |PREFEITO          |250625 |
# |ENGENHEIRO        |218313 |
# |SENADOR           |207966 |
# |GOVERNADOR        |180140 |
# |FREI              |169753 |
# |DEPUTADO          |169639 |
# |MAJOR             |166303 |
# |TENENTE           |159138 |
# |DUQUE             |150507 |
# |VISCONDE          |143396 |
# |DESEMBARGADOR     |131583 |
# |ALMIRANTE         |122449 |
# |MONSENHOR         |116173 |
# |CONSELHEIRO       |89415  |
# |PRINCESA          |87812  |
# |COMENDADOR        |87741  |
# |MINISTRO          |80975  |
# |SARGENTO          |76504  |
# |PASTOR            |74436  |
# |MARQUES           |73294  |
# |CONEGO            |72241  |
# |JORNALISTA        |70084  |
# |EXPEDICIONARIO    |68175  |
# |CONDE             |62187  |
# |IRMA              |55564  |
# |MAESTRO           |55097  |
# |BRIGADEIRO        |54839  |
# |COMANDANTE        |44166  |
# |SOLDADO           |42495  |
# |PAPA              |38424  |
# |CABO              |36205  |
# |SENHOR            |35524  |
# |MADRE             |34422  |
# |PIONEIRO          |33473  |
# |MESTRE            |26443  |
# |DOUTORA           |25914  |
# |PIO               |22698  |
# |POETA             |20464  |
# |JUIZ              |19608  |
# |CARDEAL           |18661  |
# |ESTUDANTE         |17486  |
# |TABELIAO          |17297  |
# |REVERENDO         |16928  |
# |RADIALISTA        |16787  |
# |IRMAO             |16359  |
# |AGRICULTOR        |13032  |
# |INTENDENTE        |12056  |
# |PRIMO             |11766  |
# |VIGARIO           |11752  |
# |IRMAOS            |11563  |
# |ESCRITOR          |11387  |
# |FARMACEUTICO      |11287  |
# |IMPERATRIZ        |11094  |
# |VOLUNTARIOS       |11067  |
# |ALFERES           |10893  |
# |ARQUITETO         |10562  |
# |EMBAIXADOR        |10432  |
# |COMERCIANTE       |9989   |
# |REGENTE           |9176   |
# |TENENTE CORONEL   |9153   |
# |VOLUNTARIO        |8863   |
# |DELEGADO          |8855   |
# |REI               |8680   |
# |MAE               |8605   |
# |VEREADORA         |8523   |
# |RAINHA            |8355   |
# |SENHORA           |8079   |
# |APOSTOLO          |7790   |
# |BARONESA          |7277   |
# |CANTOR            |6992   |
# |PROFETA           |6631   |
# |BISPO             |6323   |
# |AVIADOR           |6236   |
# |PINTOR            |6179   |
# |INDUSTRIAL        |6022   |
# |BACHAREL          |5991   |
# |MENINO            |5964   |
# |VICE PRESIDENTE   |5818   |
# |PRESBITERO        |5759   |
# |SAN               |5633   |
# |ATOR              |5566   |
# |PIONEIRA          |5502   |
# |IMACULADA         |5405   |
# +------------------+-------+
# only showing top 100 rows
# Column: NOM_SEGLOGR
# +------------------+-------+
# |NOM_SEGLOGR       |count  |
# +------------------+-------+
# |SEM DENOMINACAO   |1235421|
# |PRINCIPAL         |241236 |
# |ANTONIO           |238091 |
# |JOSE              |236178 |
# |A                 |220059 |
# |SEM DENOMINACAO 1 |212773 |
# |GETULIO VARGAS    |204177 |
# |B                 |200001 |
# |BRASIL            |199416 |
# |UM                |194783 |
# |SEM DENOMINACAO 2 |187739 |
# |PAULO             |186022 |
# |SETE DE SETEMBRO  |185623 |
# |DOIS              |184337 |
# |FRANCISCO         |165059 |
# |C                 |163953 |
# |JOAO              |162357 |
# |TRES              |160267 |
# |PEDRO             |153678 |
# |TIRADENTES        |151759 |
# |RUI BARBOSA       |145721 |
# |DE CAXIAS         |142892 |
# |BOA VISTA         |142338 |
# |CASTELO BRANCO    |141747 |
# |SEM DENOMINACAO 3 |135439 |
# |QUATRO            |132550 |
# |D                 |131133 |
# |BELA VISTA        |125847 |
# |AMAZONAS          |124025 |
# |SEBASTIAO         |121569 |
# |CINCO             |116970 |
# |SANTOS DUMONT     |116868 |
# |PARANA            |111845 |
# |DO RIO BRANCO     |111324 |
# |LUZIA             |107598 |
# |MINAS GERAIS      |107041 |
# |SEM DENOMINACAO 4 |106666 |
# |SEIS              |105959 |
# |E                 |105930 |
# |TANCREDO NEVES    |101724 |
# |FLORIANO PEIXOTO  |101297 |
# |SETE              |98824  |
# |DA PAZ            |98691  |
# |NOVA              |98640  |
# |QUINZE DE NOVEMBRO|95466  |
# |ISABEL            |94091  |
# |BAHIA             |93238  |
# |1                 |92354  |
# |2                 |92144  |
# |F                 |92053  |
# |GOIAS             |91369  |
# |OITO              |88951  |
# |CASTRO ALVES      |88266  |
# |RIO DE JANEIRO    |86295  |
# |CATARINA          |86178  |
# |SEM DENOMINACAO 5 |84584  |
# |MATO GROSSO       |84109  |
# |DAS FLORES        |83074  |
# |BOM JESUS         |82855  |
# |MARIA             |82822  |
# |PEDRO II          |81137  |
# |RIO BRANCO        |80446  |
# |BOA ESPERANCA     |80281  |
# |TREZE DE MAIO     |78144  |
# |BELO HORIZONTE    |77520  |
# |PROJETADA         |77290  |
# |DO CAMPO          |76741  |
# |APARECIDA         |76039  |
# |3                 |75596  |
# |NOVE              |75122  |
# |ESPIRITO SANTO    |74499  |
# |G                 |74432  |
# |MARANHAO          |73891  |
# |BRASILIA          |73400  |
# |BEIRA RIO         |73094  |
# |RITA              |71904  |
# |PERNAMBUCO        |71080  |
# |JOSE BONIFACIO    |69810  |
# |CEARA             |69281  |
# |RIO GRANDE DO SUL |68136  |
# |JORGE             |67956  |
# |DAS PALMEIRAS     |67200  |
# |SEM DENOMINACAO 6 |67152  |
# |BENJAMIN CONSTANT |65348  |
# |PARA              |64964  |
# |H                 |64737  |
# |DEODORO           |64507  |
# |CRUZ              |64125  |
# |DEZ               |63690  |
# |JOAO PESSOA       |63614  |
# |PRIMEIRO DE MAIO  |63343  |
# |4                 |62339  |
# |VARGAS            |61730  |
# |PIAUI             |61505  |
# |SANTANA           |59922  |
# |DO COMERCIO       |59851  |
# |CENTRAL           |59617  |
# |VITORIA           |59380  |
# |DE FATIMA         |58555  |
# |MIGUEL            |57871  |
# +------------------+-------+
# only showing top 100 rows
# Column: NUM_ENDERECO
# +------------+--------+
# |NUM_ENDERECO|count   |
# +------------+--------+
# |0           |26471506|
# |10          |670860  |
# |1           |648757  |
# |2           |619601  |
# |5           |614202  |
# |3           |594837  |
# |20          |567618  |
# |15          |562413  |
# |4           |558166  |
# |6           |555951  |
# |8           |542938  |
# |7           |535921  |
# |12          |529029  |
# |11          |520856  |
# |9           |504727  |
# |30          |484647  |
# |13          |475963  |
# |25          |470700  |
# |14          |460327  |
# |16          |452420  |
# |18          |439667  |
# |50          |435418  |
# |40          |432380  |
# |17          |430465  |
# |22          |428684  |
# |21          |419716  |
# |100         |409021  |
# |35          |404633  |
# |19          |400710  |
# |26          |395609  |
# |23          |371640  |
# |45          |361319  |
# |60          |358911  |
# |55          |352517  |
# |28          |345924  |
# |31          |345909  |
# |27          |340257  |
# |33          |324508  |
# |36          |323730  |
# |80          |322620  |
# |32          |316750  |
# |70          |316619  |
# |29          |315820  |
# |34          |294960  |
# |51          |291959  |
# |24          |291480  |
# |41          |291148  |
# |38          |290228  |
# |37          |286457  |
# |65          |285354  |
# |75          |276977  |
# |42          |274472  |
# |90          |273847  |
# |120         |270465  |
# |39          |268085  |
# |46          |260817  |
# |44          |258148  |
# |85          |257300  |
# |48          |257145  |
# |200         |257067  |
# |110         |251688  |
# |43          |249065  |
# |150         |246596  |
# |47          |242068  |
# |56          |240710  |
# |52          |239082  |
# |61          |235173  |
# |54          |233540  |
# |49          |232581  |
# |53          |228202  |
# |95          |227590  |
# |130         |225511  |
# |101         |222906  |
# |105         |222144  |
# |71          |220846  |
# |57          |218802  |
# |58          |217623  |
# |140         |216215  |
# |115         |211998  |
# |66          |206641  |
# |81          |204814  |
# |59          |204640  |
# |62          |203793  |
# |64          |200914  |
# |125         |200686  |
# |160         |199661  |
# |68          |196863  |
# |63          |196620  |
# |72          |195610  |
# |67          |195032  |
# |77          |194861  |
# |180         |194398  |
# |300         |194374  |
# |76          |187787  |
# |135         |187420  |
# |91          |185311  |
# |74          |184902  |
# |111         |181624  |
# |86          |181527  |
# |78          |180801  |
# +------------+--------+
# only showing top 100 rows
# Column: DSC_MODIFICADOR
# +---------------+--------+
# |DSC_MODIFICADOR|count   |
# +---------------+--------+
# |SN             |26471506|
# |SMS            |1990229 |
# |FNS            |1812007 |
# |A              |1642457 |
# |B              |829897  |
# |KM             |564054  |
# |SUCAM          |412492  |
# |FUNASA         |282341  |
# |E              |279153  |
# |C              |249437  |
# |SUS            |205188  |
# |FUNDOS         |171426  |
# |COELBA         |130789  |
# |D              |116796  |
# |1              |90326   |
# |IBGE           |87395   |
# |FA             |81853   |
# |ENERGISA       |73872   |
# |FRENTE         |63406   |
# |2              |62197   |
# |RGE            |61464   |
# |LOTE           |59495   |
# |CASA 2         |57003   |
# |COSERN         |50633   |
# |F              |47828   |
# |CASA 1         |41425   |
# |CASA           |40402   |
# |TERREO         |38632   |
# |ALTOS          |38431   |
# |N              |35658   |
# |CELG           |32441   |
# |W              |31409   |
# |SOBRADO        |31084   |
# |AME            |30935   |
# |LT             |30053   |
# |CELPE          |29214   |
# |EDAM           |28714   |
# |S              |28354   |
# |3              |27964   |
# |FVS            |24839   |
# |CASA 3         |24397   |
# |ENERGIA        |24211   |
# |BLOCO          |23760   |
# |EMBASA         |21370   |
# |CELTINS        |21169   |
# |FAD            |20051   |
# |POSTE          |19327   |
# |PADRAO         |17664   |
# |CISTERNA       |17591   |
# |MS             |16419   |
# |CT             |16180   |
# |4              |14869   |
# |FMS            |14164   |
# |G              |13244   |
# |SES            |12436   |
# |CHESP          |12061   |
# |FUNDO          |11984   |
# |C1             |11880   |
# |COMPESA        |11428   |
# |CASA 4         |11169   |
# |SAAE           |11059   |
# |LADO           |10895   |
# |LOJA           |10854   |
# |COMP           |10366   |
# |H              |10209   |
# |CEPISA         |9861    |
# |BLOCO A        |9751    |
# |BLOCO B        |9706    |
# |EQUATORIAL     |8777    |
# |L              |8686    |
# |1 ANDAR        |8532    |
# |C2             |8521    |
# |CASA A         |8446    |
# |5              |8363    |
# |SMSA           |8153    |
# |VISA           |7631    |
# |ANDAR 1        |7617    |
# |CASA B         |7252    |
# |SVS            |7200    |
# |ENEL           |7192    |
# |CRELUZ         |7138    |
# |SMSB           |7105    |
# |CEA            |7075    |
# |CEMAT          |7057    |
# |BLOCO 2        |6573    |
# |Z              |6531    |
# |INCRA          |6293    |
# |BLOCO 1        |6105    |
# |ME             |6089    |
# |6              |5604    |
# |ACE            |5491    |
# |CASA2          |5442    |
# |GME            |5322    |
# |CPS            |5295    |
# |CASA 5         |5267    |
# |ANDAR          |5170    |
# |CEEE           |5014    |
# |CERON          |4983    |
# |ENERGIS        |4969    |
# |AB             |4903    |
# +---------------+--------+
# only showing top 100 rows
# Column: NOM_COMP_ELEM1
# +----------------+--------+
# |NOM_COMP_ELEM1  |count   |
# +----------------+--------+
# |CASA            |13549321|
# |APARTAMENTO     |7377293 |
# |BLOCO           |4778967 |
# |QUADRA          |3777828 |
# |FUNDOS          |2873738 |
# |FRENTE          |1750673 |
# |TERREO          |1465392 |
# |SOBRADO         |1390163 |
# |ANDAR           |1370888 |
# |LOTE            |1266509 |
# |LOJA            |721735  |
# |LADO            |473868  |
# |QUITINETE       |401484  |
# |CHACARA         |305512  |
# |EDIFICIO        |282654  |
# |SITIO           |279555  |
# |TORRE           |240327  |
# |SALA            |229734  |
# |FAZENDA         |198478  |
# |PREDIO          |188754  |
# |BARRACAO        |170992  |
# |ANEXO           |157879  |
# |CONJUNTO        |134751  |
# |ENTRADA         |130622  |
# |SEDE            |116173  |
# |RUA INTERNA     |105851  |
# |GARAGEM         |88745   |
# |SUBSOLO         |85913   |
# |SOBRELOJA       |79055   |
# |DEPOSITO        |69557   |
# |QUARTO          |68976   |
# |PORAO           |68720   |
# |BOX             |66609   |
# |COMODO          |58214   |
# |PORTAO          |47531   |
# |ARMAZEM         |44546   |
# |BARRACA         |44121   |
# |COBERTURA       |36489   |
# |ALAMEDA INTERNA |30668   |
# |TRAVESSA INTERNA|29781   |
# |CHALE           |28132   |
# |HABITACAO       |26021   |
# |ALA             |23821   |
# |PAVIMENTO       |23624   |
# |CAIS            |23493   |
# |AVENIDA INTERNA |18554   |
# |GRUPO           |17540   |
# |PAVILHAO        |16196   |
# |CONDOMINIO      |15775   |
# |OUTROS          |15271   |
# |MODULO          |13548   |
# |PORTA           |13314   |
# |ESTANCIA        |11961   |
# |GALERIA         |11346   |
# |DEPENDENCIA     |11295   |
# |GRANJA          |10199   |
# |BANCA           |9087    |
# |LAJE            |8636    |
# |GLEBA           |6170    |
# |MANSAO          |3616    |
# |PECA            |3273    |
# |SUITE           |3135    |
# |CABINE          |1983    |
# |RESIDENCIAL     |1634    |
# |QUINTA          |1589    |
# |HANGAR          |1186    |
# |SALAO           |719     |
# |VILA            |661     |
# |GUICHE          |389     |
# |PORTARIA        |102     |
# |PALAFITA        |27      |
# +----------------+--------+
#
# Column: VAL_COMP_ELEM1
# +--------------+-------+
# |VAL_COMP_ELEM1|count  |
# +--------------+-------+
# |1             |4633007|
# |2             |3603811|
# |3             |1754053|
# |A             |1111561|
# |4             |1040218|
# |B             |936825 |
# |5             |674059 |
# |6             |512843 |
# |7             |404015 |
# |C             |357059 |
# |101           |354299 |
# |8             |347489 |
# |201           |315200 |
# |11            |302663 |
# |10            |285449 |
# |9             |284860 |
# |102           |284718 |
# |12            |279819 |
# |FUNDOS        |274026 |
# |202           |262545 |
# |13            |231383 |
# |301           |225528 |
# |14            |211580 |
# |302           |195052 |
# |D             |194204 |
# |15            |175203 |
# |21            |160979 |
# |FRENTE        |160334 |
# |16            |159227 |
# |22            |152874 |
# |103           |150571 |
# |01            |143488 |
# |17            |139758 |
# |203           |138790 |
# |18            |131722 |
# |23            |127322 |
# |E             |127234 |
# |401           |125725 |
# |02            |122784 |
# |19            |117050 |
# |24            |115686 |
# |20            |115118 |
# |104           |114013 |
# |303           |110609 |
# |402           |109952 |
# |31            |107602 |
# |DIREITO       |107454 |
# |204           |105757 |
# |32            |101195 |
# |F             |95259  |
# |TERREO        |90496  |
# |25            |89479  |
# |ESQUERDO      |87568  |
# |304           |86207  |
# |33            |81833  |
# |03            |81333  |
# |26            |80497  |
# |34            |75062  |
# |41            |73722  |
# |501           |73591  |
# |27            |73339  |
# |403           |68591  |
# |42            |68491  |
# |28            |67932  |
# |G             |65682  |
# |502           |63817  |
# |29            |63157  |
# |30            |62530  |
# |04            |62177  |
# |601           |57867  |
# |CASA 2        |57254  |
# |404           |56981  |
# |43            |55490  |
# |H             |54765  |
# |51            |54392  |
# |35            |54253  |
# |CASA          |53670  |
# |44            |52750  |
# |602           |50742  |
# |52            |50160  |
# |36            |49438  |
# |701           |47547  |
# |105           |46682  |
# |05            |46148  |
# |61            |45233  |
# |CASA 1        |44690  |
# |UNICO         |44221  |
# |37            |43772  |
# |I             |43507  |
# |38            |43487  |
# |SN            |42392  |
# |702           |41413  |
# |06            |41045  |
# |53            |40912  |
# |40            |40600  |
# |503           |40459  |
# |62            |39947  |
# |0             |39936  |
# |801           |39863  |
# |205           |39623  |
# +--------------+-------+
# only showing top 100 rows
# Column: NOM_COMP_ELEM2
# +----------------+-------+
# |NOM_COMP_ELEM2  |count  |
# +----------------+-------+
# |APARTAMENTO     |5142142|
# |LOTE            |2726197|
# |CASA            |1015447|
# |FUNDOS          |425051 |
# |ANDAR           |407511 |
# |BLOCO           |392890 |
# |FRENTE          |272585 |
# |TERREO          |270634 |
# |QUADRA          |170501 |
# |SOBRADO         |138024 |
# |LADO            |127449 |
# |QUITINETE       |85600  |
# |LOJA            |76313  |
# |SALA            |56650  |
# |ENTRADA         |55913  |
# |EDIFICIO        |47557  |
# |CHACARA         |46469  |
# |TORRE           |40926  |
# |CONJUNTO        |34669  |
# |MODULO          |27362  |
# |SEDE            |26563  |
# |PREDIO          |25743  |
# |ALA             |24702  |
# |RUA INTERNA     |21407  |
# |SITIO           |17880  |
# |QUARTO          |16808  |
# |SUBSOLO         |14624  |
# |FAZENDA         |14070  |
# |PORTAO          |13853  |
# |ANEXO           |13523  |
# |PORTA           |9102   |
# |BARRACAO        |8710   |
# |COBERTURA       |8693   |
# |SOBRELOJA       |8182   |
# |GRUPO           |7526   |
# |GLEBA           |6917   |
# |PAVIMENTO       |6073   |
# |GARAGEM         |5985   |
# |COMODO          |5429   |
# |BOX             |5337   |
# |PORAO           |4936   |
# |TRAVESSA INTERNA|4671   |
# |DEPOSITO        |4303   |
# |ARMAZEM         |3430   |
# |ALAMEDA INTERNA |3061   |
# |CHALE           |3022   |
# |BARRACA         |2796   |
# |HABITACAO       |2630   |
# |AVENIDA INTERNA |2327   |
# |OUTROS          |2239   |
# |DEPENDENCIA     |1730   |
# |LAJE            |1715   |
# |CAIS            |1357   |
# |ESTANCIA        |1148   |
# |GALERIA         |1135   |
# |SUITE           |1111   |
# |PAVILHAO        |834    |
# |MANSAO          |821    |
# |GRANJA          |703    |
# |PECA            |501    |
# |BANCA           |309    |
# |QUINTA          |205    |
# |CABINE          |136    |
# |HANGAR          |72     |
# |SALAO           |36     |
# |RESIDENCIAL     |31     |
# |VILA            |30     |
# |GUICHE          |25     |
# |CONDOMINIO      |9      |
# |PALAFITA        |3      |
# +----------------+-------+
#
# Column: VAL_COMP_ELEM2
# +--------------+------+
# |VAL_COMP_ELEM2|count |
# +--------------+------+
# |1             |680201|
# |2             |582599|
# |3             |353592|
# |4             |251612|
# |5             |177939|
# |11            |175708|
# |12            |170480|
# |101           |162935|
# |6             |155372|
# |13            |152935|
# |102           |150925|
# |201           |149010|
# |14            |147847|
# |7             |138933|
# |202           |138394|
# |8             |130535|
# |10            |127373|
# |103           |120526|
# |301           |119454|
# |21            |116512|
# |302           |116180|
# |9             |115573|
# |104           |114883|
# |22            |112412|
# |203           |112167|
# |A             |110828|
# |204           |107583|
# |B             |104149|
# |15            |100655|
# |303           |100157|
# |23            |99500 |
# |304           |97177 |
# |24            |96056 |
# |16            |94875 |
# |401           |84535 |
# |17            |84528 |
# |402           |83039 |
# |18            |80844 |
# |31            |79963 |
# |32            |78159 |
# |403           |75226 |
# |404           |73545 |
# |19            |69757 |
# |33            |68481 |
# |20            |67805 |
# |34            |66599 |
# |01            |52381 |
# |25            |51769 |
# |41            |49528 |
# |26            |48839 |
# |42            |48518 |
# |02            |44027 |
# |43            |43524 |
# |44            |42240 |
# |27            |41923 |
# |28            |39796 |
# |TERREO        |37956 |
# |03            |36273 |
# |C             |35578 |
# |501           |33637 |
# |04            |33230 |
# |105           |33212 |
# |502           |32592 |
# |DIREITO       |31884 |
# |29            |31642 |
# |30            |30936 |
# |106           |30912 |
# |205           |29727 |
# |503           |29718 |
# |ESQUERDO      |29540 |
# |504           |29086 |
# |206           |28083 |
# |51            |27233 |
# |305           |26651 |
# |52            |26431 |
# |35            |26007 |
# |306           |25506 |
# |36            |24378 |
# |05            |24341 |
# |06            |23865 |
# |107           |23244 |
# |53            |23164 |
# |54            |22809 |
# |D             |22802 |
# ...
# |504           |579  |
# |17            |578  |
# |106           |550  |
# |AREA 5        |512  |
# |42            |496  |
# |001           |491  |
# |41            |487  |
# |002           |477  |
# |205           |461  |
# |43            |458  |
# |44            |446  |
# |107           |431  |
# |003           |422  |
# |206           |412  |
# |004           |412  |
# |108           |410  |
# |18            |409  |
# |FUNDOS        |395  |
# |52            |391  |
# |E             |389  |
# |01 AO 06      |384  |
# |05            |379  |
# |06            |365  |
# |19            |365  |
# |601           |351  |
# |602           |339  |
# |305           |334  |
# |603           |331  |
# |604           |330  |
# |51            |330  |
# |53            |316  |
# |BRANCO        |314  |
# |25            |313  |
# |20            |308  |
# |306           |306  |
# |08            |302  |
# |54            |298  |
# |SEDE          |298  |
# |36            |285  |
# |VERDE         |282  |
# |702           |281  |
# |701           |281  |
# |207           |280  |
# |07            |277  |
# |1 AO 13       |277  |
# +--------------+-----+
# only showing top 100 rows
# Column: NOM_COMP_ELEM5
# +----------------+-----+
# |NOM_COMP_ELEM5  |count|
# +----------------+-----+
# |APARTAMENTO     |16438|
# |CASA            |1293 |
# |LOTE            |711  |
# |PORTAO          |643  |
# |FUNDOS          |547  |
# |ENTRADA         |487  |
# |TERREO          |486  |
# |LOJA            |398  |
# |LADO            |395  |
# |SOBRADO         |386  |
# |FRENTE          |333  |
# |SITIO           |307  |
# |TORRE           |304  |
# |QUITINETE       |297  |
# |SALA            |294  |
# |ANDAR           |258  |
# |GARAGEM         |221  |
# |PORTA           |177  |
# |BARRACAO        |92   |
# |TRAVESSA INTERNA|69   |
# |COBERTURA       |61   |
# |BOX             |51   |
# |CHACARA         |51   |
# |ANEXO           |49   |
# |SEDE            |46   |
# |QUARTO          |45   |
# |PAVIMENTO       |35   |
# |PREDIO          |32   |
# |DEPOSITO        |29   |
# |COMODO          |28   |
# |EDIFICIO        |27   |
# |SOBRELOJA       |26   |
# |RUA INTERNA     |20   |
# |CONJUNTO        |20   |
# |FAZENDA         |18   |
# |DEPENDENCIA     |17   |
# |HABITACAO       |16   |
# |CHALE           |16   |
# |BLOCO           |11   |
# |GALERIA         |10   |
# |ARMAZEM         |10   |
# |QUADRA          |7    |
# |SUITE           |7    |
# |ALA             |6    |
# |OUTROS          |6    |
# |MODULO          |6    |
# |ALAMEDA INTERNA |5    |
# |BARRACA         |5    |
# |SUBSOLO         |5    |
# |BANCA           |4    |
# |GRANJA          |4    |
# |AVENIDA INTERNA |3    |
# |CAIS            |3    |
# |CABINE          |3    |
# |GLEBA           |2    |
# |GRUPO           |1    |
# |HANGAR          |1    |
# |PECA            |1    |
# |LAJE            |1    |
# |QUINTA          |1    |
# |SALAO           |1    |
# |PORAO           |1    |
# +----------------+-----+
#
# Column: VAL_COMP_ELEM5
# +--------------+-----+
# |VAL_COMP_ELEM5|count|
# +--------------+-----+
# |1             |1048 |
# |2             |1008 |
# |101           |711  |
# |102           |711  |
# |202           |668  |
# |201           |655  |
# |103           |629  |
# |104           |617  |
# |203           |592  |
# |204           |570  |
# |5             |525  |
# |3             |517  |
# |301           |502  |
# |302           |492  |
# |303           |488  |
# |304           |476  |
# |002           |393  |
# |401           |392  |
# |001           |391  |
# |402           |388  |
# |403           |385  |
# |404           |380  |
# |003           |374  |
# |004           |370  |
# |01            |366  |
# |02            |365  |
# |4             |341  |
# |BRANCO        |175  |
# |11            |166  |
# |12            |145  |
# |18E33         |120  |
# |DIREITO       |118  |
# |6             |107  |
# |37            |106  |
# |PRETO         |103  |
# |18R           |102  |
# |13            |93   |
# |14            |90   |
# |03            |86   |
# |ESQUERDO      |81   |
# |08            |77   |
# |7             |77   |
# |10            |74   |
# |04            |74   |
# |8             |72   |
# |22            |70   |
# |105           |69   |
# |23            |69   |
# |MADEIRA       |68   |
# |21            |67   |
# |106           |63   |
# |24            |62   |
# |31            |61   |
# |43            |58   |
# |METAL         |58   |
# |32            |57   |
# |05            |56   |
# |34            |56   |
# |33            |56   |
# |41            |54   |
# |44            |53   |
# |42            |53   |
# |CINZA         |52   |
# |06            |51   |
# |205           |51   |
# |9             |50   |
# |07            |48   |
# |LOJAS         |47   |
# |206           |46   |
# |107           |44   |
# |501           |43   |
# |108           |43   |
# |502           |42   |
# |504           |42   |
# |503           |41   |
# |601           |40   |
# |604           |39   |
# |603           |39   |
# |602           |39   |
# |COMUM         |38   |
# |305           |38   |
# |TERREO        |35   |
# |207           |34   |
# |09            |33   |
# |208           |33   |
# |ALUMINIO      |31   |
# |703           |31   |
# |804           |31   |
# |801           |31   |
# |802           |31   |
# |701           |31   |
# |803           |31   |
# |704           |31   |
# |DIREITA       |31   |
# |406           |30   |
# |702           |30   |
# |405           |30   |
# |306           |30   |
# |BRANCA        |29   |
# |BARRAS        |29   |
# +--------------+-----+
# only showing top 100 rows
# Column: LATITUDE
# +----------+-----+
# |LATITUDE  |count|
# +----------+-----+
# |-20.703377|1004 |
# |-25.347031|877  |
# |-23.523219|874  |
# |-23.550103|796  |
# |-17.739901|774  |
# |-22.593764|746  |
# |-17.734873|706  |
# |-23.486777|677  |
# |-23.554553|661  |
# |-23.525337|637  |
# |-12.939607|623  |
# |-23.541159|618  |
# |-22.912943|616  |
# |-15.609266|611  |
# |-23.499574|609  |
# |-15.816648|608  |
# |-12.299453|606  |
# |-12.989096|605  |
# |-23.584077|596  |
# |-3.741296 |590  |
# |-15.631013|587  |
# |-3.775399 |586  |
# |-23.552242|578  |
# |-23.676831|578  |
# |-23.53357 |576  |
# |-23.004742|574  |
# |-25.435868|574  |
# |-12.850908|572  |
# |-22.990128|571  |
# |-30.103382|570  |
# |-30.047392|570  |
# |-29.909384|569  |
# |-23.486815|561  |
# |-23.4947  |558  |
# |-8.10921  |552  |
# |-23.350983|552  |
# |-21.685831|550  |
# |-3.796107 |548  |
# |-22.969163|543  |
# |-16.73603 |540  |
# |-23.403507|538  |
# |-23.147221|536  |
# |-22.986807|531  |
# |-16.690506|529  |
# |-29.974273|525  |
# |-25.507241|524  |
# |-22.830044|524  |
# |-1.368142 |524  |
# |-22.898586|523  |
# |-23.558598|522  |
# |-1.366498 |521  |
# |-22.944376|520  |
# |-23.637042|518  |
# |-1.367163 |518  |
# |-27.597874|514  |
# |-23.447538|513  |
# |-23.522835|513  |
# |-22.994425|511  |
# |-22.816887|511  |
# |-18.913462|511  |
# |-12.84362 |510  |
# |-7.94144  |510  |
# |-22.815962|509  |
# |-25.44258 |509  |
# |-23.534894|508  |
# |-12.935327|506  |
# |-22.823495|505  |
# |-23.616274|504  |
# |-29.894745|502  |
# |-8.225901 |502  |
# |-29.777963|501  |
# |-5.18786  |500  |
# |-23.553361|499  |
# |-23.608231|499  |
# |-23.634805|499  |
# |-25.440065|497  |
# |-23.6344  |497  |
# |-23.548848|497  |
# |-1.343462 |496  |
# |-23.494112|495  |
# |-12.967036|493  |
# |-23.326474|492  |
# |-3.742396 |492  |
# |-21.724113|491  |
# |-29.909031|491  |
# |-25.494858|488  |
# |-23.498995|485  |
# |-23.675002|484  |
# |-20.11612 |484  |
# |-26.874357|483  |
# |-22.87637 |480  |
# |-22.957914|480  |
# |-13.006392|479  |
# |-12.939801|479  |
# |-15.673685|476  |
# |-23.562324|476  |
# |-23.441309|475  |
# |-23.618828|474  |
# |-18.956389|473  |
# |-12.699878|471  |
# +----------+-----+
# only showing top 100 rows
# Column: LONGITUDE
# +----------+-----+
# |LONGITUDE |count|
# +----------+-----+
# |-48.919712|1011 |
# |-49.285104|884  |
# |-46.771631|842  |
# |-48.630703|778  |
# |-43.299967|763  |
# |-48.636012|718  |
# |-38.493439|668  |
# |-46.869385|658  |
# |-46.577765|644  |
# |-48.449551|633  |
# |-46.780648|629  |
# |-38.411958|615  |
# |-38.477901|613  |
# |-48.014896|612  |
# |-56.092535|611  |
# |-49.262218|605  |
# |-38.938995|596  |
# |-51.166153|585  |
# |-56.070087|584  |
# |-51.149382|582  |
# |-51.140757|582  |
# |-46.71801 |582  |
# |-46.711459|580  |
# |-43.341258|579  |
# |-38.27261 |572  |
# |-47.420249|568  |
# |-46.614423|567  |
# |-38.534125|566  |
# |-51.190671|560  |
# |-34.907105|560  |
# |-43.253808|556  |
# |-43.348514|555  |
# |-46.433876|550  |
# |-49.28577 |549  |
# |-48.96653 |547  |
# |-48.430815|541  |
# |-38.561402|539  |
# |-49.161181|538  |
# |-46.869371|537  |
# |-43.309944|535  |
# |-46.449917|527  |
# |-48.448495|525  |
# |-34.862486|524  |
# |-48.448557|524  |
# |-49.347413|522  |
# |-46.691822|520  |
# |-46.536819|518  |
# |-48.660753|518  |
# |-34.945771|512  |
# |-46.816919|512  |
# |-43.302617|511  |
# |-38.334193|508  |
# |-43.355278|507  |
# |-51.117566|507  |
# |-43.582163|506  |
# |-47.254225|504  |
# |-43.545211|504  |
# |-48.328439|503  |
# |-51.168929|502  |
# |-49.277485|501  |
# |-55.960197|501  |
# |-46.593859|501  |
# |-46.543782|500  |
# |-49.272544|500  |
# |-51.168708|500  |
# |-46.876777|499  |
# |-51.189352|497  |
# |-38.377612|495  |
# |-49.156086|494  |
# |-48.69643 |493  |
# |-37.303067|493  |
# |-46.453589|491  |
# |-38.379176|491  |
# |-46.593828|491  |
# |-38.541104|491  |
# |-46.650871|488  |
# |-46.651646|487  |
# |-38.409385|487  |
# |-48.435319|486  |
# |-51.1593  |485  |
# |-43.313904|484  |
# |-40.292132|484  |
# |-46.548771|482  |
# |-46.62859 |476  |
# |-46.763559|475  |
# |-46.866717|474  |
# |-48.321808|474  |
# |-35.179802|472  |
# |-38.345242|471  |
# |-49.108097|467  |
# |-43.177262|467  |
# |-46.759663|465  |
# |-46.956516|465  |
# |-48.959152|464  |
# |-48.641121|464  |
# |-43.342751|464  |
# |-43.327755|463  |
# |-43.347506|461  |
# |-38.37971 |461  |
# |-46.87437 |461  |
# +----------+-----+
# only showing top 100 rows
# Column: NV_GEO_COORD
# +------------+---------+
# |NV_GEO_COORD|count    |
# +------------+---------+
# |1           |103943000|
# |2           |6054561  |
# |3           |747276   |
# |4           |333132   |
# |6           |14937    |
# |5           |9969     |
# +------------+---------+
#
# Column: COD_ESPECIE
# +-----------+--------+
# |COD_ESPECIE|count   |
# +-----------+--------+
# |1          |90600065|
# |6          |11706713|
# |3          |4058385 |
# |7          |3541442 |
# |8          |579798  |
# |4          |264445  |
# |5          |247510  |
# |2          |104517  |
# +-----------+--------+
#
# Column: DSC_ESTABELECIMENTO
# +-------------------------------+------+
# |DSC_ESTABELECIMENTO            |count |
# +-------------------------------+------+
# |VAGO                           |306558|
# |BAR                            |285895|
# |DEPOSITO                       |239801|
# |GARAGEM                        |232729|
# |SEM NOME                       |120131|
# |GALPAO                         |107896|
# |SEM DENOMINACAO                |105884|
# |IGREJA                         |82349 |
# |SALAO DE BELEZA                |80926 |
# |SITIO                          |74906 |
# |CRIACAO DE GADO                |72132 |
# |OFICINA                        |71979 |
# |CURRAL                         |70727 |
# |LOJA VAGA                      |70269 |
# |MERCEARIA                      |69576 |
# |LOJA                           |57994 |
# |OFICINA MECANICA               |57012 |
# |CASA DE FARINHA                |51357 |
# |FAZENDA                        |49116 |
# |BARBEARIA                      |46520 |
# |LANCHONETE                     |44972 |
# |BARRACAO                       |41468 |
# |IGREJA ASSEMBLEIA DE DEUS      |41394 |
# |SALAO                          |41023 |
# |ASSEMBLEIA DE DEUS             |40331 |
# |COMERCIO                       |40326 |
# |ESCRITORIO                     |39826 |
# |LOJA DE ROUPAS                 |37959 |
# |BORRACHARIA                    |37265 |
# |MERCADINHO                     |36993 |
# |ARMAZEM                        |35207 |
# |MARCENARIA                     |32596 |
# |ESTACIONAMENTO                 |32491 |
# |ESTABELECIMENTO VAGO           |30837 |
# |CRIACAO DE BOVINOS             |30476 |
# |RESTAURANTE                    |27768 |
# |PADARIA                        |26595 |
# |IGREJA CATOLICA                |26147 |
# |SERRALHERIA                    |25939 |
# |PONTO COMERCIAL                |24834 |
# |ESCRITORIO DE ADVOCACIA        |23163 |
# |CHACARA                        |23139 |
# |CRIACAO DE ANIMAIS             |22701 |
# |LOJA FECHADA                   |21570 |
# |PECUARIA                       |20706 |
# |LAVA JATO                      |19544 |
# |CRIACAO DE GALINHA             |18602 |
# |FECHADO                        |18311 |
# |PONTO VAGO                     |17387 |
# |IGREJA EVANGELICA              |16441 |
# |ESCOLA                         |15782 |
# |SN                             |15756 |
# |SALAO VAGO                     |15622 |
# |CASA                           |15444 |
# |SEM IDENTIFICACAO              |15254 |
# |CONSULTORIO ODONTOLOGICO       |15002 |
# |MERCADO                        |14970 |
# |CRIACAO DE GALINHAS            |14796 |
# |AGRICULTURA                    |14358 |
# |POSTO DE SAUDE                 |14171 |
# |SALA VAGA                      |13776 |
# |MECANICA                       |13130 |
# |FERRO VELHO                    |12848 |
# |NAO TEM                        |12774 |
# |ROCA                           |12763 |
# |BARRACA                        |12684 |
# |SORVETERIA                     |12660 |
# |FARMACIA                       |12405 |
# |SALA COMERCIAL                 |12402 |
# |CEMITERIO                      |12260 |
# |ADVOCACIA                      |12195 |
# |PONTO COMERCIAL VAGO           |11747 |
# |GALINHEIRO                     |11661 |
# |LOJA DE ROUPA                  |11632 |
# |ACOUGUE                        |11402 |
# |TERRENO                        |11031 |
# |PLANTACAO                      |10818 |
# |ESCRITORIO DE CONTABILIDADE    |10731 |
# |GADO                           |10707 |
# |BRECHO                         |10591 |
# |VAZIO                          |10492 |
# |ACADEMIA                       |10472 |
# |AGROPECUARIO                   |10177 |
# |DEPOSITO DE BEBIDAS            |10159 |
# |IGREJA ADVENTISTA DO SETIMO DIA|9841  |
# |SALAO DE FESTAS                |9839  |
# |GRANJA                         |9733  |
# |CAPELA                         |9658  |
# |CRIACAO DE AVES                |9527  |
# |BAZAR                          |9477  |
# |METALURGICA                    |9394  |
# |CULTIVO DE CAFE                |9336  |
# |CENTRO ESPIRITA                |9131  |
# |ESTABULO                       |8972  |
# |PAIOL                          |8831  |
# |EMPRESA                        |8544  |
# |SERRARIA                       |8438  |
# |GALPAO VAGO                    |8402  |
# |IGREJA PENTECOSTAL             |8376  |
# |PRODUCAO DE LEITE              |8332  |
# +-------------------------------+------+
# only showing top 100 rows
# Column: COD_INDICADOR_ESTAB_ENDERECO
# +----------------------------+--------+
# |COD_INDICADOR_ESTAB_ENDERECO|count   |
# +----------------------------+--------+
# |1                           |16434895|
# |2                           |259666  |
# |4                           |129276  |
# |3                           |41736   |
# +----------------------------+--------+
#
# Column: COD_INDICADOR_CONST_ENDERECO
# +----------------------------+-------+
# |COD_INDICADOR_CONST_ENDERECO|count  |
# +----------------------------+-------+
# |1                           |3427798|
# |2                           |105139 |
# |3                           |33155  |
# |4                           |16413  |
# +----------------------------+-------+
#
# Column: COD_INDICADOR_FINALIDADE_CONST
# +------------------------------+-------+
# |COD_INDICADOR_FINALIDADE_CONST|count  |
# +------------------------------+-------+
# |1                             |2770405|
# |4                             |533814 |
# |2                             |230178 |
# |3                             |37565  |
# +------------------------------+-------+
#
# Column: COD_TIPO_ESPECI
# +---------------+--------+
# |COD_TIPO_ESPECI|count   |
# +---------------+--------+
# |101            |73817837|
# |103            |13942183|
# |102            |2442534 |
# |104            |502028  |
# +---------------+--------+
#
# Column: UF
# [Stage 113:=================================>                    (24 + 12) / 39]
# +---+--------+
# |UF |count   |
# +---+--------+
# |SP |22953725|
# |MG |12038190|
# |BA |9047296 |
# |RJ |8962200 |
# |RS |6456747 |
# |PR |6122025 |
# |PE |5120482 |
# |CE |4750642 |
# |SC |4181139 |
# |GO |3960937 |
# |PA |3911170 |
# |MA |3257843 |
# |PB |2228886 |
# |ES |2221348 |
# |MT |1985314 |
# |PI |1891421 |
# |RN |1845003 |
# |AM |1658970 |
# |AL |1626565 |
# |MS |1507819 |
# |DF |1318887 |
# |SE |1258755 |
# |RO |965370  |
# |TO |848437  |
# |AC |410524  |
# |AP |312665  |
# |RR |260515  |
# +---+--------+

# %% [markdown]
# ## Look if null values are consistent

# %% [markdown]
# ### Based on empty strings

# %%
from pyspark.sql import functions as F

categorical_cols = [
    f.name for f in df.schema.fields if str(f.dataType) == "StringType()"
]

empty_string_exprs = [
    F.count(F.when(F.col(c) == "", c)).alias(c) for c in categorical_cols
]

df.select(empty_string_exprs).show(vertical=True, truncate=False)
# Out:
# [Stage 116:========================================>             (29 + 10) / 39]
# -RECORD 0-----------------------------
#  COD_SETOR                      | 0
#  CEP                            | 0
#  DSC_LOCALIDADE                 | 0
#  NOM_TIPO_SEGLOGR               | 0
#  NOM_TITULO_SEGLOGR             | 0
#  NOM_SEGLOGR                    | 0
#  DSC_MODIFICADOR                | 0
#  NOM_COMP_ELEM1                 | 0
#  VAL_COMP_ELEM1                 | 0
#  NOM_COMP_ELEM2                 | 0
#  VAL_COMP_ELEM2                 | 0
#  NOM_COMP_ELEM3                 | 0
#  VAL_COMP_ELEM3                 | 0
#  NOM_COMP_ELEM4                 | 0
#  VAL_COMP_ELEM4                 | 0
#  NOM_COMP_ELEM5                 | 0
#  VAL_COMP_ELEM5                 | 0
#  DSC_ESTABELECIMENTO            | 0
#  COD_INDICADOR_ESTAB_ENDERECO   | 0
#  COD_INDICADOR_CONST_ENDERECO   | 0
#  COD_INDICADOR_FINALIDADE_CONST | 0
#  UF                             | 0

# %% [markdown]
# ### Based on String which sings value is undefined

# %%
import json
from pyspark.sql import functions as F


def get_undefined_expressions_map(col_name: str):
    try:
        with open("config/inconsistent_annotations.json", "r") as f:
            undefined_expressions_map = json.load(f)
            print(f"Loaded undefined expressions for column: {col_name}")
    except FileNotFoundError:
        print("Warning: inconsistent_annotations.json file not found.")
        undefined_expressions_map = {}
    return undefined_expressions_map.get(col_name, [])


def is_undefined(col: F.Column, col_name: str) -> F.Column:
    undefined_expressions = get_undefined_expressions_map(col_name)
    if not undefined_expressions:
        return F.lit(False)
    return col.cast("string").isin(*undefined_expressions)

# %%
import pandas as pd

categorical_cols = [
    f.name for f in df.schema.fields if str(f.dataType) == "StringType()"
]
undefined_count = []
for col_name in categorical_cols:
    print(f"Column: {col_name}")
    count_undefined_df = (
        df.filter(is_undefined(F.col(col_name), col_name))
        .groupBy(F.col(col_name))
        .count()
        .alias("count")
        .orderBy(F.col("count").desc())
    )

    if count_undefined_df.count() > 0:
        total_undefined_count = count_undefined_df.agg(F.sum("count")).collect()[0][0]
        percentage = round((total_undefined_count / total_rows) * 100, 3)
        undefined_count.append(
            {"column": col_name, "count": total_undefined_count, "pct_db": percentage}
        )

pd.DataFrame(undefined_count)
# Out:
# Column: COD_SETOR
# Loaded undefined expressions for column: COD_SETOR
# Column: CEP
# Loaded undefined expressions for column: CEP
# Column: DSC_LOCALIDADE
# Loaded undefined expressions for column: DSC_LOCALIDADE
# Column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Column: NOM_TITULO_SEGLOGR
# Loaded undefined expressions for column: NOM_TITULO_SEGLOGR
# Column: NOM_SEGLOGR
# Loaded undefined expressions for column: NOM_SEGLOGR
# Column: DSC_MODIFICADOR
# Loaded undefined expressions for column: DSC_MODIFICADOR
# Column: NOM_COMP_ELEM1
# Loaded undefined expressions for column: NOM_COMP_ELEM1
# Column: VAL_COMP_ELEM1
# Loaded undefined expressions for column: VAL_COMP_ELEM1
# Column: NOM_COMP_ELEM2
# Loaded undefined expressions for column: NOM_COMP_ELEM2
# Column: VAL_COMP_ELEM2
# Loaded undefined expressions for column: VAL_COMP_ELEM2
# Column: NOM_COMP_ELEM3
# Loaded undefined expressions for column: NOM_COMP_ELEM3
# Column: VAL_COMP_ELEM3
# Loaded undefined expressions for column: VAL_COMP_ELEM3
# Column: NOM_COMP_ELEM4
# Loaded undefined expressions for column: NOM_COMP_ELEM4
# Column: VAL_COMP_ELEM4
# Loaded undefined expressions for column: VAL_COMP_ELEM4
# Column: NOM_COMP_ELEM5
# Loaded undefined expressions for column: NOM_COMP_ELEM5
# Column: VAL_COMP_ELEM5
# Loaded undefined expressions for column: VAL_COMP_ELEM5
# Column: DSC_ESTABELECIMENTO
# Loaded undefined expressions for column: DSC_ESTABELECIMENTO
# Column: COD_INDICADOR_ESTAB_ENDERECO
# Loaded undefined expressions for column: COD_INDICADOR_ESTAB_ENDERECO
# Column: COD_INDICADOR_CONST_ENDERECO
# Loaded undefined expressions for column: COD_INDICADOR_CONST_ENDERECO
# Column: COD_INDICADOR_FINALIDADE_CONST
# Loaded undefined expressions for column: COD_INDICADOR_FINALIDADE_CONST
# Column: UF
# Loaded undefined expressions for column: UF
#              column    count  pct_db
# 0    DSC_LOCALIDADE     7089   0.006
# 1  NOM_TIPO_SEGLOGR    28041   0.025
# 2       NOM_SEGLOGR  1236474   1.113

# %%
total_rows = df.count()


# Build both conditions (sem filtro / com filtro) in a single pass
exprs = []
for c in df.columns:
    # Sem filtro: apenas remove nulos
    not_null_cond = F.col(c).isNotNull()

    # Com filtro: remove nulos + expressões indefinidas (apenas colunas string)
    if c in categorical_cols:
        full_cond = F.col(c).isNotNull() & (~is_undefined(F.col(c), c))
    else:
        full_cond = not_null_cond

    exprs.append(
        F.struct(
            F.lit(c).alias("column"),
            (F.count(F.when(not_null_cond, F.lit(1))) / F.lit(total_rows) * 100).alias(
                "pct_filtro_null_basico"
            ),
            (F.count(F.when(full_cond, F.lit(1))) / F.lit(total_rows) * 100).alias(
                "pct_com_filtro_null_strito"
            ),
        )
    )

result = (
    df.select(F.array(*exprs).alias("stats"))
    .selectExpr("explode(stats) as stats")
    .select(
        "stats.column",
        "stats.pct_filtro_null_basico",
        "stats.pct_com_filtro_null_strito",
    )
    .withColumn(
        "diferenca",
        F.round(
            F.col("pct_com_filtro_null_strito") - F.col("pct_filtro_null_basico"), 4
        ),
    )
    .withColumn("pct_filtro_null_basico", F.round(F.col("pct_filtro_null_basico"), 4))
    .withColumn(
        "pct_com_filtro_null_strito", F.round(F.col("pct_com_filtro_null_strito"), 4)
    )
)

result.orderBy(F.col("pct_com_filtro_null_strito").desc()).show(
    df.columns.__len__(), truncate=False
)
# Out:
# Loaded undefined expressions for column: COD_SETOR
# Loaded undefined expressions for column: CEP
# Loaded undefined expressions for column: DSC_LOCALIDADE
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: NOM_TITULO_SEGLOGR
# Loaded undefined expressions for column: NOM_SEGLOGR
# Loaded undefined expressions for column: DSC_MODIFICADOR
# Loaded undefined expressions for column: NOM_COMP_ELEM1
# Loaded undefined expressions for column: VAL_COMP_ELEM1
# Loaded undefined expressions for column: NOM_COMP_ELEM2
# Loaded undefined expressions for column: VAL_COMP_ELEM2
# Loaded undefined expressions for column: NOM_COMP_ELEM3
# Loaded undefined expressions for column: VAL_COMP_ELEM3
# Loaded undefined expressions for column: NOM_COMP_ELEM4
# Loaded undefined expressions for column: VAL_COMP_ELEM4
# Loaded undefined expressions for column: NOM_COMP_ELEM5
# Loaded undefined expressions for column: VAL_COMP_ELEM5
# Loaded undefined expressions for column: DSC_ESTABELECIMENTO
# Loaded undefined expressions for column: COD_INDICADOR_ESTAB_ENDERECO
# Loaded undefined expressions for column: COD_INDICADOR_CONST_ENDERECO
# Loaded undefined expressions for column: COD_INDICADOR_FINALIDADE_CONST
# Loaded undefined expressions for column: UF
# [Stage 197:=====================================================> (38 + 1) / 39]
# +------------------------------+----------------------+--------------------------+---------+
# |column                        |pct_filtro_null_basico|pct_com_filtro_null_strito|diferenca|
# +------------------------------+----------------------+--------------------------+---------+
# |COD_UNICO_ENDERECO            |100.0                 |100.0                     |0.0      |
# |COD_UF                        |100.0                 |100.0                     |0.0      |
# |COD_MUNICIPIO                 |100.0                 |100.0                     |0.0      |
# |COD_DISTRITO                  |100.0                 |100.0                     |0.0      |
# |COD_SUBDISTRITO               |100.0                 |100.0                     |0.0      |
# |COD_SETOR                     |100.0                 |100.0                     |0.0      |
# |NUM_QUADRA                    |100.0                 |100.0                     |0.0      |
# |NUM_FACE                      |100.0                 |100.0                     |0.0      |
# |CEP                           |100.0                 |100.0                     |0.0      |
# |NUM_ENDERECO                  |100.0                 |100.0                     |0.0      |
# |LATITUDE                      |100.0                 |100.0                     |0.0      |
# |LONGITUDE                     |100.0                 |100.0                     |0.0      |
# |NV_GEO_COORD                  |100.0                 |100.0                     |0.0      |
# |COD_ESPECIE                   |100.0                 |100.0                     |0.0      |
# |UF                            |100.0                 |100.0                     |0.0      |
# |DSC_LOCALIDADE                |100.0                 |99.9936                   |-0.0064  |
# |NOM_TIPO_SEGLOGR              |100.0                 |99.9748                   |-0.0252  |
# |NOM_SEGLOGR                   |100.0                 |98.8871                   |-1.1129  |
# |COD_TIPO_ESPECI               |81.6402               |81.6402                   |0.0      |
# |NOM_COMP_ELEM1                |40.3953               |40.3953                   |0.0      |
# |DSC_MODIFICADOR               |34.4179               |34.4179                   |0.0      |
# |VAL_COMP_ELEM1                |29.4555               |29.4555                   |0.0      |
# |COD_INDICADOR_ESTAB_ENDERECO  |15.1801               |15.1801                   |0.0      |
# |NOM_TITULO_SEGLOGR            |14.0174               |14.0174                   |0.0      |
# |DSC_ESTABELECIMENTO           |13.6328               |13.6328                   |0.0      |
# |NOM_COMP_ELEM2                |10.6805               |10.6805                   |0.0      |
# |VAL_COMP_ELEM2                |9.5257                |9.5257                    |0.0      |
# |COD_INDICADOR_CONST_ENDERECO  |3.2245                |3.2245                    |0.0      |
# |COD_INDICADOR_FINALIDADE_CONST|3.215                 |3.215                     |0.0      |
# |NOM_COMP_ELEM3                |2.2072                |2.2072                    |0.0      |
# |VAL_COMP_ELEM3                |1.9215                |1.9215                    |0.0      |
# |NOM_COMP_ELEM4                |0.226                 |0.226                     |0.0      |
# |VAL_COMP_ELEM4                |0.1843                |0.1843                    |0.0      |
# |NOM_COMP_ELEM5                |0.0223                |0.0223                    |0.0      |
# |VAL_COMP_ELEM5                |0.0204                |0.0204                    |0.0      |
# +------------------------------+----------------------+--------------------------+---------+

# %% [markdown]
# #### Plot differences

# %%
from pyspark.sql import functions as F
import plotly.graph_objects as go
import plotly.io as pio


pio.renderers.default = "png"

diff_df = result.filter(F.col("diferenca") != 0.0).orderBy(F.col("diferenca").asc())

diff_rows = diff_df.select("column", "diferenca").collect()

labels = [row["column"] for row in diff_rows]
data = [round(row["diferenca"], 4) for row in diff_rows]

fig = go.Figure(
    go.Bar(
        x=data,
        y=labels,
        orientation="h",
        marker=dict(color="red"),
        text=[f"{v:.4f}" for v in data],
        textposition="outside",
        hovertemplate="%{y}: %{x:.4f} p.p.<extra></extra>",
    )
)

fig.update_layout(
    title="Diferença de fulfillment (com filtro mais restritivo - filtro nulo básico)",
    xaxis_title="Diferença (p.p.)",
    yaxis_title="Coluna",
    yaxis=dict(autorange="reversed"),  # mantém a maior diferença no topo
    template="plotly_white",
    height=max(400, len(labels) * 40 + 100),
    width=2000,
)

# %% [markdown]
# ### Caracterização casos onde tem indefinidos

# %%
df.filter(
    is_undefined(F.col("NOM_SEGLOGR"), "NOME_LOGRADOURO")
    | is_undefined(F.col("NOM_TIPO_SEGLOGR"), "NOM_TIPO_SEGLOGR")
    | is_undefined(F.col("DSC_LOCALIDADE"), "DSC_LOCALIDADE")
).count()
# Out:
# Loaded undefined expressions for column: NOME_LOGRADOURO
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: DSC_LOCALIDADE
# 35130

# %% [markdown]
# #### Por espécie domicílio

# %%
mapping = CNEFE_VARS_DICT["COD_ESPECIE"]["valores"]
var_analyzed = "COD_ESPECIE"
(
    df
    .groupBy(var_analyzed)
    .count()
    .withColumn(
        var_analyzed,
        F.col(var_analyzed).cast("string")
    )
    .replace(
        mapping,
        subset=[var_analyzed]
    )
    .orderBy(F.col("count").desc())
    .show(500, truncate=False)
)
# Out:
# +-------------------------------------+--------+
# |COD_ESPECIE                          |count   |
# +-------------------------------------+--------+
# |Domicílio particular                 |90600065|
# |Estabelecimento de outras finalidades|11706713|
# |Estabelecimento agropecuário         |4058385 |
# |Edificação em construção ou reforma  |3541442 |
# |Estabelecimento religioso            |579798  |
# |Estabelecimento de ensino            |264445  |
# |Estabelecimento de saúde             |247510  |
# |Domicílio coletivo                   |104517  |
# +-------------------------------------+--------+

# %%
mapping = CNEFE_VARS_DICT["COD_ESPECIE"]["valores"]
var_analyzed = "COD_ESPECIE"
(
    df
    .filter(
        is_undefined(F.col("NOM_SEGLOGR"), "NOME_LOGRADOURO")
        | is_undefined(F.col("NOM_TIPO_SEGLOGR"), "NOM_TIPO_SEGLOGR")
        | is_undefined(F.col("DSC_LOCALIDADE"), "DSC_LOCALIDADE")
    )
    .groupBy(var_analyzed)
    .count()
    .withColumn(
        var_analyzed,
        F.col(var_analyzed).cast("string")
    )
    .replace(
        mapping,
        subset=[var_analyzed]
    )
    .orderBy(F.col("count").desc())
    .show(500, truncate=False)
)
# Out:
# Loaded undefined expressions for column: NOME_LOGRADOURO
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: DSC_LOCALIDADE
# [Stage 225:===============================>                      (23 + 12) / 39]
# +-------------------------------------+-----+
# |COD_ESPECIE                          |count|
# +-------------------------------------+-----+
# |Domicílio particular                 |25887|
# |Estabelecimento agropecuário         |3648 |
# |Estabelecimento de outras finalidades|3058 |
# |Edificação em construção ou reforma  |2214 |
# |Estabelecimento religioso            |188  |
# |Estabelecimento de ensino            |67   |
# |Estabelecimento de saúde             |35   |
# |Domicílio coletivo                   |33   |
# +-------------------------------------+-----+

# %% [markdown]
# #### Por Descricao Localidade

# %%
var_analyzed = "COD_TIPO_ESPECI"
mapping = CNEFE_VARS_DICT[var_analyzed]["valores"]

(
    df
    .groupBy(var_analyzed)
    .count()
    .withColumn(
        var_analyzed,
        F.col(var_analyzed).cast("string")
    )
    .replace(
        mapping,
        subset=[var_analyzed]
    )
    .orderBy(F.col("count").desc())
    .show(500, truncate=False)
)
# Out:
# +-----------------------------+--------+
# |COD_TIPO_ESPECI              |count   |
# +-----------------------------+--------+
# |Casa                         |73817837|
# |NULL                         |20398293|
# |Apartamento                  |13942183|
# |Casa de vila ou em condomínio|2442534 |
# |Outros                       |502028  |
# +-----------------------------+--------+

# %%
var_analyzed = "COD_TIPO_ESPECI"
mapping = CNEFE_VARS_DICT[var_analyzed]["valores"]

(
    df
    .filter(
        is_undefined(F.col("NOM_SEGLOGR"), "NOME_LOGRADOURO")
        | is_undefined(F.col("NOM_TIPO_SEGLOGR"), "NOM_TIPO_SEGLOGR")
        | is_undefined(F.col("DSC_LOCALIDADE"), "DSC_LOCALIDADE")
    )
    .groupBy(var_analyzed)
    .count()
    .withColumn(
        var_analyzed,
        F.col(var_analyzed).cast("string")
    )
    .replace(
        mapping,
        subset=[var_analyzed]
    )
    .orderBy(F.col("count").desc())
    .show(500, truncate=False)
)
# Out:
# Loaded undefined expressions for column: NOME_LOGRADOURO
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: DSC_LOCALIDADE
# [Stage 229:======================>                               (16 + 12) / 39]
# +-----------------------------+-----+
# |COD_TIPO_ESPECI              |count|
# +-----------------------------+-----+
# |Casa                         |24498|
# |NULL                         |9210 |
# |Apartamento                  |916  |
# |Casa de vila ou em condomínio|288  |
# |Outros                       |218  |
# +-----------------------------+-----+

# %% [markdown]
# #### Por mapa de geolocalização

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geobr


def plot_brazil_coordinates(
    df,
    longitude_col="longitude",
    latitude_col="latitude",
    sample_fraction=None,
    seed=42,
    figsize=(10, 10),
    markersize=1,
    alpha=0.4,
):
    coordinates = (
        df
        .select(longitude_col, latitude_col)
        .dropna()
    )

    # Sampling is optional
    if sample_fraction is not None:
        coordinates = coordinates.sample(
            withReplacement=False,
            fraction=sample_fraction,
            seed=seed
        )

    pdf = coordinates.toPandas()
    gdf = gpd.GeoDataFrame(
        pdf,
        geometry=gpd.points_from_xy(
            pdf[longitude_col],
            pdf[latitude_col]
        ),
        crs="EPSG:4326"
    )
    brazil = geobr.read_country(year=2020)
    fig, ax = plt.subplots(figsize=figsize)

    brazil.plot(
        ax=ax,
        color="white",
        edgecolor="black",
        linewidth=0.5
    )

    gdf.plot(
        ax=ax,
        markersize=markersize,
        alpha=alpha
    )

    ax.set_axis_off()
    plt.tight_layout()
    plt.show()

    return gdf

# %%
plot_brazil_coordinates(
    df,
    longitude_col="LONGITUDE",
    latitude_col="LATITUDE",
    seed=42,
    figsize=(20, 20),
    sample_fraction=0.5,
    markersize=1,
    alpha=0.4
)
# Out:
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/pyspark/sql/pandas/conversion.py:298: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
#           LONGITUDE   LATITUDE                     geometry
# 0        -38.441379 -12.901406  POINT (-38.44138 -12.90141)
# 1        -38.496721 -12.957379  POINT (-38.49672 -12.95738)
# 2        -38.398671 -12.898274  POINT (-38.39867 -12.89827)
# 3        -38.427660 -12.932600   POINT (-38.42766 -12.9326)
# 4        -38.430853 -12.901955  POINT (-38.43085 -12.90196)
# ...             ...        ...                          ...
# 55544836 -53.029582 -16.857355  POINT (-53.02958 -16.85736)
# 55544837 -53.032556 -16.855317  POINT (-53.03256 -16.85532)
# 55544838 -53.032066 -16.855162  POINT (-53.03207 -16.85516)
# 55544839 -53.031247 -16.855082  POINT (-53.03125 -16.85508)
# 55544840 -53.031815 -16.855113  POINT (-53.03182 -16.85511)
#
# [55544841 rows x 3 columns]

# %%
plot_brazil_coordinates(
    df.filter(
        is_undefined(F.col("NOM_SEGLOGR"), "NOME_LOGRADOURO")
        | is_undefined(F.col("NOM_TIPO_SEGLOGR"), "NOM_TIPO_SEGLOGR")
        | is_undefined(F.col("DSC_LOCALIDADE"), "DSC_LOCALIDADE")
    ),
    longitude_col="LONGITUDE",
    latitude_col="LATITUDE",
    seed=42,
    figsize=(20, 20),
    markersize=1,
    alpha=0.4
)
# Out:
# Loaded undefined expressions for column: NOME_LOGRADOURO
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: DSC_LOCALIDADE
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/pyspark/sql/pandas/conversion.py:298: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host 'release-assets.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# country_2020_simplified.parquet: 100%|██████████| 532k/532k [00:00<00:00, 5.03MB/s]
#        LONGITUDE   LATITUDE                     geometry
# 0     -38.408629 -12.937092  POINT (-38.40863 -12.93709)
# 1     -38.478405 -12.942371   POINT (-38.4784 -12.94237)
# 2     -38.477177 -12.940975  POINT (-38.47718 -12.94098)
# 3     -38.479024 -12.941092  POINT (-38.47902 -12.94109)
# 4     -38.484349 -12.938707  POINT (-38.48435 -12.93871)
# ...          ...        ...                          ...
# 35125 -60.272059   4.445975    POINT (-60.27206 4.44598)
# 35126 -60.261967   4.450541    POINT (-60.26197 4.45054)
# 35127 -60.261967   4.450541    POINT (-60.26197 4.45054)
# 35128 -38.743856  -8.661036   POINT (-38.74386 -8.66104)
# 35129 -38.728798  -8.687449    POINT (-38.7288 -8.68745)
#
# [35130 rows x 3 columns]

# %% [markdown]
# #### Análise amostra

# %%
df.filter(
    is_undefined(F.col("NOM_SEGLOGR"), "NOME_LOGRADOURO")
    | is_undefined(F.col("NOM_TIPO_SEGLOGR"), "NOM_TIPO_SEGLOGR")
    | is_undefined(F.col("DSC_LOCALIDADE"), "DSC_LOCALIDADE")
).sample(fraction=0.01).toPandas()
# Out:
# Loaded undefined expressions for column: NOME_LOGRADOURO
# Loaded undefined expressions for column: NOM_TIPO_SEGLOGR
# Loaded undefined expressions for column: DSC_LOCALIDADE
# /home/lucas-vital/projects/brazilian_address_linkage/.venv/lib/python3.13/site-packages/pyspark/sql/pandas/conversion.py:298: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
#      COD_UNICO_ENDERECO  COD_UF  COD_MUNICIPIO  COD_DISTRITO  COD_SUBDISTRITO  \
# 0              28075161      29        2927408     292740805      29274080522
# 1              91116400      29        2927408     292740805      29274080522
# 2             222440458      29        2927408     292740805      29274080522
# 3              27932045      29        2927408     292740805      29274080522
# 4              27861639      29        2927408     292740805      29274080522
# ..                  ...     ...            ...           ...              ...
# 328           216044555      13        1303502     130350205      13035020500
# 329            99876317      13        1303502     130350205      13035020500
# 330            36096346      31        3156205     315620505      31562050500
# 331             7520790      17        1713957     171395705      17139570500
# 332             7520802      17        1713957     171395705      17139570500
#
#             COD_SETOR  NUM_QUADRA  NUM_FACE       CEP  \
# 0    292740805220552P           1         2  40354555
# 1    292740805220361P           1         2  40349435
# 2    292740805220094P           2         4  40357290
# 3    292740805220135P           2         3  40352360
# 4    292740805220099P           2         1  40352212
# ..                ...         ...       ...       ...
# 328  130350205000074P           3        13  69860000
# 329  130350205000074P           3        14  69860000
# 330  315620505000007P          18        11  36604000
# 331  171395705000006P           0         3  77850000
# 332  171395705000006P           0         3  77850000
#
#                DSC_LOCALIDADE  ...   LATITUDE  LONGITUDE NV_GEO_COORD  \
# 0    FAZENDA GRANDE DO RETIRO  ... -12.939596 -38.482947            1
# 1                ALTO DO PERU  ... -12.938319 -38.485504            4
# 2    FAZENDA GRANDE DO RETIRO  ... -12.938014 -38.482112            1
# 3              FAZENDA GRANDE  ... -12.942043 -38.478063            1
# 4              FAZENDA GRANDE  ... -12.940373 -38.478862            1
# ..                        ...  ...        ...        ...          ...
# 328              CIDADE BAIXA  ...  -7.717655 -67.002881            1
# 329              CIDADE BAIXA  ...  -7.718111 -67.003933            1
# 330             SAO FRANCISCO  ... -21.622951 -43.013316            1
# 331             NAO INFORMADO  ...  -7.187910 -48.616733            1
# 332             NAO INFORMADO  ...  -7.225936 -48.648196            1
#
#      COD_ESPECIE DSC_ESTABELECIMENTO COD_INDICADOR_ESTAB_ENDERECO  \
# 0              1                 NaN                          NaN
# 1              1                 NaN                          NaN
# 2              1                 NaN                          NaN
# 3              1                 NaN                          NaN
# 4              1                 NaN                          NaN
# ..           ...                 ...                          ...
# 328            6    OFICINA MAURICIO                            1
# 329            1                 NaN                          NaN
# 330            1                 NaN                          NaN
# 331            1                 NaN                          NaN
# 332            1                 NaN                          NaN
#
#     COD_INDICADOR_CONST_ENDERECO COD_INDICADOR_FINALIDADE_CONST  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ..                           ...                            ...
# 328                          NaN                            NaN
# 329                          NaN                            NaN
# 330                          NaN                            NaN
# 331                          NaN                            NaN
# 332                          NaN                            NaN
#
#     COD_TIPO_ESPECI  UF
# 0             101.0  BA
# 1             103.0  BA
# 2             101.0  BA
# 3             101.0  BA
# 4             101.0  BA
# ..              ...  ..
# 328             NaN  AM
# 329           101.0  AM
# 330           101.0  MG
# 331           101.0  TO
# 332           101.0  TO
#
# [333 rows x 35 columns]

# %% [markdown]
# ## Data Cleaning & Linkage Options

# %% [markdown]
# ### Options for Cleaning Data
#
# Consider the following data cleaning steps:
#
# - **Trim whitespace** — Remove leading and trailing whitespace from string values
#   *(e.g., `" john smith "` → `"john smith"`)*
# - **Remove special characters** from string values
#   *(e.g., `"O'Hara"` → `"Ohara"`)*
# - **Standardize date formats** as strings in `yyyy-mm-dd` format
# - **Expand abbreviations** to full words
#   *(e.g., standardize `"St."` and `"Street"` to `"Street"`)*
# - **Remove non-null undefined values**
# - **Apply phonetics** to address names
#
#
# ### Fields for Probabilistic Linkage
#
# When performing probabilistic linkage, consider using the following fields:
# ```yaml
# - COD_UNICO_ENDERECO
# - COD_UF
# - COD_MUNICIPIO
# - COD_DISTRITO
# - COD_SUBDISTRITO
# - COD_SETOR
# - NUM_QUADRA
# - NUM_FACE
# - CEP
# - NUM_ENDERECO
# - LATITUDE
# - LONGITUDE
# - NV_GEO_COORD
# - DSC_LOCALIDADE
# - NOM_TIPO_SEGLOGR
# - OM_SEGLOGR
# ```
